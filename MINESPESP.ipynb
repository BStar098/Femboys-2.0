# %%
# Esta es una modificacion del script original para google colab, para que funcione en github codespaces
# Hecho por @LUCAST o @Lucast1574 o @Lucast_1574 en github y otras redes sociales
# Solo versiones +1.17
# Versiones disponibles testeadas:
# - 1.20.4
# - 1.20.3
# - 1.20.2
# - 1.20.1
# - 1.20
# - 1.19.4
# - 1.19.3
# - 1.19.2
# - 1.19.1
# - 1.19
# - 1.18.2
# - 1.18.1
# - 1.18
# - 1.17.1




version = '1.20.1' # Version de Minecraft a usar

#Chose server type. Currently available versions:
# - paper (Lo más vanilla. Es lo mismo que SPIGOT, bukkit, etc)
# - forge (Para usar MODS. Es básicamente FORGE) [Aviso, la instalación tarda APROX 10-15 min, al ejecutar el primer paso, esperar a que ponga COMPLETADO]
# - fabric (Para jugar Fabric. Es una alternativa a Forge)
# - vanilla (Minecraft Vanilla sin mods ni plugins)
# - snapshot (En "version" tendrás que poner el nombre de la SNAPSHOT, EJ: 23w42a)
# - mohist (Versión de Minecraft que combina Forge y Bukkit) 1.20.1 29/09/24 ultima version disponible
# - catserver (Versión de Minecraft que combina Forge y Bukkit) 1.18.2 29/09/24 ultima version disponible
# - purpur (Versión de Minecraft que combina paper y Bukkit)

server_type = 'forge'

#Importa librerias necesarias para el funcionamiento del script 

import os
import requests
import json


server_directory = "Minecraft-server"

# Crea el directorio del servidor en codespace



# Inicio interno... Descarga el servidor 




jar_name = {'forge': 'forge.jar'}



# Correr en un camino especifico



# %cd "/workspaces/codespaces-jupyter/Minecraft-server"
# !java -jar forge.jar --installServer



# Guarda el archivo de configuración localmente
colabconfig = {"server_type": server_type, "server_version": version}
with open("colabconfig.json", 'w') as config_file:
    json.dump(colabconfig, config_file)

# Imprime un mensaje de finalización
print('Completado!')
# Cambie el eula a true para aceptar los términos de Minecraft
# !echo "eula=true" >> eula.txt
# Out:
# /home/codespace/.local/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]
# /workspaces/codespaces-jupyter/Minecraft-server
# JVM info: Microsoft - 21.0.2 - 21.0.2+13-LTS
# java.net.preferIPv4Stack=true
# Current Time: 16/04/2024 22:21:05
# Host: files.minecraftforge.net [104.21.58.163, 172.67.161.211]
# Host: maven.minecraftforge.net [104.21.58.163, 172.67.161.211]
# Host: libraries.minecraft.net [13.107.246.41, 13.107.213.41]
# Host: launchermeta.mojang.com [13.107.213.41, 13.107.246.41]
# Host: piston-meta.mojang.com [13.107.253.41, 13.107.226.41]
# Host: sessionserver.mojang.com [13.107.246.41, 13.107.213.41]
# Host: authserver.mojang.com [Unknown]
# Target Directory: .
# Data kindly mirrored by CreeperHost at https://www.creeperhost.net/
# Considering minecraft server jar
# Downloading libraries
# Found 0 additional library directories
# Considering library cpw.mods:securejarhandler:2.1.10
#   File exists: Checksum validated.
# Considering library org.ow2.asm:asm:9.6
#   File exists: Checksum validated.
# Considering library org.ow2.asm:asm-commons:9.6
#   File exists: Checksum validated.
# Considering library org.ow2.asm:asm-tree:9.6
#   File exists: Checksum validated.
# Considering library org.ow2.asm:asm-util:9.6
#   Downloading library from https://maven.creeperhost.net/org/ow2/asm/asm-util/9.6/asm-util-9.6.jar
#     Download completed: Checksum validated.
# Considering library org.ow2.asm:asm-analysis:9.6
#   Downloading library from https://maven.creeperhost.net/org/ow2/asm/asm-analysis/9.6/asm-analysis-9.6.jar
#     Download completed: Checksum validated.
# Considering library net.minecraftforge:accesstransformers:8.0.4
#   File exists: Checksum validated.
# Considering library org.antlr:antlr4-runtime:4.9.1
#   File exists: Checksum validated.
# Considering library net.minecraftforge:eventbus:6.0.5
#   File exists: Checksum validated.
# Considering library net.minecraftforge:forgespi:7.0.1
#   File exists: Checksum validated.
# Considering library net.minecraftforge:coremods:5.1.2
#   Downloading library from https://maven.creeperhost.net/net/minecraftforge/coremods/5.1.2/coremods-5.1.2.jar
#     Download completed: Checksum validated.
# Considering library cpw.mods:modlauncher:10.0.9
#   File exists: Checksum validated.
# Considering library net.minecraftforge:unsafe:0.2.0
#   File exists: Checksum validated.
# Considering library net.minecraftforge:mergetool:1.1.5:api
#   File exists: Checksum validated.
# Considering library com.electronwill.night-config:core:3.6.4
#   File exists: Checksum validated.
# Considering library com.electronwill.night-config:toml:3.6.4
#   File exists: Checksum validated.
# Considering library org.apache.maven:maven-artifact:3.8.5
#   File exists: Checksum validated.
# Considering library net.jodah:typetools:0.6.3
#   File exists: Checksum validated.
# Considering library net.minecrell:terminalconsoleappender:1.2.0
#   File exists: Checksum validated.
# Considering library org.jline:jline-reader:3.12.1
#   File exists: Checksum validated.
# Considering library org.jline:jline-terminal:3.12.1
#   File exists: Checksum validated.
# Considering library org.spongepowered:mixin:0.8.5
#   File exists: Checksum validated.
# Considering library org.openjdk.nashorn:nashorn-core:15.3
#   File exists: Checksum validated.
# Considering library net.minecraftforge:JarJarSelector:0.3.19
#   File exists: Checksum validated.
# Considering library net.minecraftforge:JarJarMetadata:0.3.19
#   File exists: Checksum validated.
# Considering library cpw.mods:bootstraplauncher:1.1.2
#   File exists: Checksum validated.
# Considering library net.minecraftforge:JarJarFileSystems:0.3.19
#   File exists: Checksum validated.
# Considering library net.minecraftforge:fmlloader:1.20.1-47.2.21
#   Downloading library from https://maven.creeperhost.net/net/minecraftforge/fmlloader/1.20.1-47.2.21/fmlloader-1.20.1-47.2.21.jar
#     Download completed: Checksum validated.
# Considering library net.minecraftforge:fmlearlydisplay:1.20.1-47.2.21
#   Downloading library from https://maven.creeperhost.net/net/minecraftforge/fmlearlydisplay/1.20.1-47.2.21/fmlearlydisplay-1.20.1-47.2.21.jar
#     Download completed: Checksum validated.
# Considering library com.github.jponge:lzma-java:1.3
#   File exists: Checksum validated.
# Considering library com.google.code.findbugs:jsr305:3.0.2
#   File exists: Checksum validated.
# Considering library com.google.code.gson:gson:2.10.1
#   File exists: Checksum validated.
# Considering library com.google.errorprone:error_prone_annotations:2.1.3
#   File exists: Checksum validated.
# Considering library com.google.guava:guava:25.1-jre
#   File exists: Checksum validated.
# Considering library com.google.j2objc:j2objc-annotations:1.1
#   File exists: Checksum validated.
# Considering library com.nothome:javaxdelta:2.0.1
#   File exists: Checksum validated.
# Considering library commons-io:commons-io:2.4
#   File exists: Checksum validated.
# Considering library de.oceanlabs.mcp:mcp_config:1.20.1-20230612.114412@zip
#   File exists: Checksum validated.
# Considering library de.siegmar:fastcsv:2.2.2
#   File exists: Checksum validated.
# Considering library net.minecraftforge:ForgeAutoRenamingTool:0.1.22:all
#   File exists: Checksum validated.
# Considering library net.minecraftforge:binarypatcher:1.1.1
#   File exists: Checksum validated.
# Considering library net.minecraftforge:fmlcore:1.20.1-47.2.21
#   Downloading library from https://maven.creeperhost.net/net/minecraftforge/fmlcore/1.20.1-47.2.21/fmlcore-1.20.1-47.2.21.jar
#     Download completed: Checksum validated.
# Considering library net.minecraftforge:fmlearlydisplay:1.20.1-47.2.21
#   File exists: Checksum validated.
# Considering library net.minecraftforge:fmlloader:1.20.1-47.2.21
#   File exists: Checksum validated.
# Considering library net.minecraftforge:forge:1.20.1-47.2.21:universal
#   Downloading library from https://maven.creeperhost.net/net/minecraftforge/forge/1.20.1-47.2.21/forge-1.20.1-47.2.21-universal.jar
#     Download completed: Checksum validated.
# Considering library net.minecraftforge:installertools:1.4.1
#   File exists: Checksum validated.
# Considering library net.minecraftforge:jarsplitter:1.1.4
#   File exists: Checksum validated.
# Considering library net.minecraftforge:javafmllanguage:1.20.1-47.2.21
#   Downloading library from https://maven.creeperhost.net/net/minecraftforge/javafmllanguage/1.20.1-47.2.21/javafmllanguage-1.20.1-47.2.21.jar
#     Download completed: Checksum validated.
# Considering library net.minecraftforge:lowcodelanguage:1.20.1-47.2.21
#   Downloading library from https://maven.creeperhost.net/net/minecraftforge/lowcodelanguage/1.20.1-47.2.21/lowcodelanguage-1.20.1-47.2.21.jar
#     Download completed: Checksum validated.
# Considering library net.minecraftforge:mclanguage:1.20.1-47.2.21
#   Downloading library from https://maven.creeperhost.net/net/minecraftforge/mclanguage/1.20.1-47.2.21/mclanguage-1.20.1-47.2.21.jar
#     Download completed: Checksum validated.
# Considering library net.minecraftforge:srgutils:0.4.3
#   File exists: Checksum validated.
# Considering library net.minecraftforge:srgutils:0.4.9
#   File exists: Checksum validated.
# Considering library net.minecraftforge:srgutils:0.5.6
#   File exists: Checksum validated.
# Considering library net.sf.jopt-simple:jopt-simple:5.0.4
#   File exists: Checksum validated.
# Considering library net.sf.jopt-simple:jopt-simple:6.0-alpha-3
#   File exists: Checksum validated.
# Considering library org.checkerframework:checker-qual:2.0.0
#   File exists: Checksum validated.
# Considering library org.codehaus.mojo:animal-sniffer-annotations:1.14
#   File exists: Checksum validated.
# Considering library org.ow2.asm:asm-analysis:9.2
#   File exists: Checksum validated.
# Considering library org.ow2.asm:asm-commons:9.2
#   File exists: Checksum validated.
# Considering library org.ow2.asm:asm-commons:9.6
#   File exists: Checksum validated.
# Considering library org.ow2.asm:asm-tree:9.2
#   File exists: Checksum validated.
# Considering library org.ow2.asm:asm-tree:9.6
#   File exists: Checksum validated.
# Considering library org.ow2.asm:asm:9.2
#   File exists: Checksum validated.
# Considering library org.ow2.asm:asm:9.6
#   File exists: Checksum validated.
# Considering library trove:trove:1.0.2
#   File exists: Checksum validated.
# Created Temporary Directory: /tmp/forge_installer409980787791956550
#   Extracting: /data/server.lzma
# Building Processors
# ===============================================================================
#   MainClass: net.minecraftforge.installertools.ConsoleTool
#   Classpath:
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/minecraftforge/installertools/1.4.1/installertools-1.4.1.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/sf/jopt-simple/jopt-simple/6.0-alpha-3/jopt-simple-6.0-alpha-3.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/com/google/code/gson/gson/2.10.1/gson-2.10.1.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/de/siegmar/fastcsv/2.2.2/fastcsv-2.2.2.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/minecraftforge/srgutils/0.5.6/srgutils-0.5.6.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/org/ow2/asm/asm-commons/9.6/asm-commons-9.6.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/org/ow2/asm/asm-tree/9.6/asm-tree-9.6.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/org/ow2/asm/asm/9.6/asm-9.6.jar
#   Args: --task, EXTRACT_FILES, --archive, /workspaces/codespaces-jupyter/Minecraft-server/forge.jar, --from, data/run.sh, --to, /workspaces/codespaces-jupyter/Minecraft-server/./run.sh, --exec, /workspaces/codespaces-jupyter/Minecraft-server/./run.sh, --from, data/run.bat, --to, /workspaces/codespaces-jupyter/Minecraft-server/./run.bat, --from, data/user_jvm_args.txt, --to, /workspaces/codespaces-jupyter/Minecraft-server/./user_jvm_args.txt, --optional, /workspaces/codespaces-jupyter/Minecraft-server/./user_jvm_args.txt, --from, data/win_args.txt, --to, /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/minecraftforge/forge/1.20.1-47.2.21/win_args.txt, --from, data/unix_args.txt, --to, /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/minecraftforge/forge/1.20.1-47.2.21/unix_args.txt
# Task: EXTRACT_FILES
# Archive: /workspaces/codespaces-jupyter/Minecraft-server/forge.jar
# Extract: data/run.sh
#          /workspaces/codespaces-jupyter/Minecraft-server/./run.sh
# Extract: data/run.bat
#          /workspaces/codespaces-jupyter/Minecraft-server/./run.bat
# Extract: data/user_jvm_args.txt
#          /workspaces/codespaces-jupyter/Minecraft-server/./user_jvm_args.txt
# Extract: data/win_args.txt
#          /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/minecraftforge/forge/1.20.1-47.2.21/win_args.txt
# Extract: data/unix_args.txt
#          /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/minecraftforge/forge/1.20.1-47.2.21/unix_args.txt
# Exec:    /workspaces/codespaces-jupyter/Minecraft-server/./run.sh
# ===============================================================================
#   MainClass: net.minecraftforge.installertools.ConsoleTool
#   Classpath:
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/minecraftforge/installertools/1.4.1/installertools-1.4.1.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/sf/jopt-simple/jopt-simple/6.0-alpha-3/jopt-simple-6.0-alpha-3.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/com/google/code/gson/gson/2.10.1/gson-2.10.1.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/de/siegmar/fastcsv/2.2.2/fastcsv-2.2.2.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/minecraftforge/srgutils/0.5.6/srgutils-0.5.6.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/org/ow2/asm/asm-commons/9.6/asm-commons-9.6.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/org/ow2/asm/asm-tree/9.6/asm-tree-9.6.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/org/ow2/asm/asm/9.6/asm-9.6.jar
#   Args: --task, BUNDLER_EXTRACT, --input, /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/minecraft/server/1.20.1/server-1.20.1.jar, --output, /workspaces/codespaces-jupyter/Minecraft-server/./libraries/, --libraries
# Task: BUNDLER_EXTRACT
# Input:   /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/minecraft/server/1.20.1/server-1.20.1.jar
# Output:  /workspaces/codespaces-jupyter/Minecraft-server/./libraries
# All:     false
# JarOnly: false
# Libs:    true
# File already exists, and hash verified
# File already exists, and hash verified
# File already exists, and hash verified
# File already exists, and hash verified
# File already exists, and hash verified
# File already exists, and hash verified
# File already exists, and hash verified
# File already exists, and hash verified
# File already exists, and hash verified
# File already exists, and hash verified
# File already exists, and hash verified
# File already exists, and hash verified
# File already exists, and hash verified
# File already exists, and hash verified
# File already exists, and hash verified
# File already exists, and hash verified
# File already exists, and hash verified
# File already exists, and hash verified
# File already exists, and hash verified
# File already exists, and hash verified
# File already exists, and hash verified
# File already exists, and hash verified
# File already exists, and hash verified
# File already exists, and hash verified
# File already exists, and hash verified
# File already exists, and hash verified
# File already exists, and hash verified
# File already exists, and hash verified
# File already exists, and hash verified
# ===============================================================================
#   MainClass: net.minecraftforge.installertools.ConsoleTool
#   Classpath:
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/minecraftforge/installertools/1.4.1/installertools-1.4.1.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/sf/jopt-simple/jopt-simple/6.0-alpha-3/jopt-simple-6.0-alpha-3.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/com/google/code/gson/gson/2.10.1/gson-2.10.1.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/de/siegmar/fastcsv/2.2.2/fastcsv-2.2.2.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/minecraftforge/srgutils/0.5.6/srgutils-0.5.6.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/org/ow2/asm/asm-commons/9.6/asm-commons-9.6.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/org/ow2/asm/asm-tree/9.6/asm-tree-9.6.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/org/ow2/asm/asm/9.6/asm-9.6.jar
#   Args: --task, BUNDLER_EXTRACT, --input, /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/minecraft/server/1.20.1/server-1.20.1.jar, --output, /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/minecraft/server/1.20.1-20230612.114412/server-1.20.1-20230612.114412-unpacked.jar, --jar-only
# Task: BUNDLER_EXTRACT
# Input:   /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/minecraft/server/1.20.1/server-1.20.1.jar
# Output:  /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/minecraft/server/1.20.1-20230612.114412/server-1.20.1-20230612.114412-unpacked.jar
# All:     false
# JarOnly: true
# Libs:    false
# File already exists, and hash verified
# ===============================================================================
#   MainClass: net.minecraftforge.installertools.ConsoleTool
#   Classpath:
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/minecraftforge/installertools/1.4.1/installertools-1.4.1.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/sf/jopt-simple/jopt-simple/6.0-alpha-3/jopt-simple-6.0-alpha-3.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/com/google/code/gson/gson/2.10.1/gson-2.10.1.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/de/siegmar/fastcsv/2.2.2/fastcsv-2.2.2.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/minecraftforge/srgutils/0.5.6/srgutils-0.5.6.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/org/ow2/asm/asm-commons/9.6/asm-commons-9.6.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/org/ow2/asm/asm-tree/9.6/asm-tree-9.6.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/org/ow2/asm/asm/9.6/asm-9.6.jar
#   Args: --task, MCP_DATA, --input, /workspaces/codespaces-jupyter/Minecraft-server/./libraries/de/oceanlabs/mcp/mcp_config/1.20.1-20230612.114412/mcp_config-1.20.1-20230612.114412.zip, --output, /workspaces/codespaces-jupyter/Minecraft-server/./libraries/de/oceanlabs/mcp/mcp_config/1.20.1-20230612.114412/mcp_config-1.20.1-20230612.114412-mappings.txt, --key, mappings
# Task: MCP_DATA
# Input:  /workspaces/codespaces-jupyter/Minecraft-server/./libraries/de/oceanlabs/mcp/mcp_config/1.20.1-20230612.114412/mcp_config-1.20.1-20230612.114412.zip
# Output: /workspaces/codespaces-jupyter/Minecraft-server/./libraries/de/oceanlabs/mcp/mcp_config/1.20.1-20230612.114412/mcp_config-1.20.1-20230612.114412-mappings.txt
# Key:    mappings
# Extracting: config/joined.tsrg
# ===============================================================================
#   MainClass: net.minecraftforge.installertools.ConsoleTool
#   Classpath:
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/minecraftforge/installertools/1.4.1/installertools-1.4.1.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/sf/jopt-simple/jopt-simple/6.0-alpha-3/jopt-simple-6.0-alpha-3.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/com/google/code/gson/gson/2.10.1/gson-2.10.1.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/de/siegmar/fastcsv/2.2.2/fastcsv-2.2.2.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/minecraftforge/srgutils/0.5.6/srgutils-0.5.6.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/org/ow2/asm/asm-commons/9.6/asm-commons-9.6.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/org/ow2/asm/asm-tree/9.6/asm-tree-9.6.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/org/ow2/asm/asm/9.6/asm-9.6.jar
#   Args: --task, DOWNLOAD_MOJMAPS, --version, 1.20.1, --side, server, --output, /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/minecraft/server/1.20.1-20230612.114412/server-1.20.1-20230612.114412-mappings.txt
# Task: DOWNLOAD_MOJMAPS
# MC Version: 1.20.1
# Side:       server
# Output:     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/minecraft/server/1.20.1-20230612.114412/server-1.20.1-20230612.114412-mappings.txt
# Sanitize:   false
# Format:     TSRG
# Skip:       false
# Downloaded Mojang mappings for 1.20.1
# ===============================================================================
#   MainClass: net.minecraftforge.installertools.ConsoleTool
#   Classpath:
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/minecraftforge/installertools/1.4.1/installertools-1.4.1.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/sf/jopt-simple/jopt-simple/6.0-alpha-3/jopt-simple-6.0-alpha-3.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/com/google/code/gson/gson/2.10.1/gson-2.10.1.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/de/siegmar/fastcsv/2.2.2/fastcsv-2.2.2.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/minecraftforge/srgutils/0.5.6/srgutils-0.5.6.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/org/ow2/asm/asm-commons/9.6/asm-commons-9.6.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/org/ow2/asm/asm-tree/9.6/asm-tree-9.6.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/org/ow2/asm/asm/9.6/asm-9.6.jar
#   Args: --task, MERGE_MAPPING, --left, /workspaces/codespaces-jupyter/Minecraft-server/./libraries/de/oceanlabs/mcp/mcp_config/1.20.1-20230612.114412/mcp_config-1.20.1-20230612.114412-mappings.txt, --right, /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/minecraft/server/1.20.1-20230612.114412/server-1.20.1-20230612.114412-mappings.txt, --output, /workspaces/codespaces-jupyter/Minecraft-server/./libraries/de/oceanlabs/mcp/mcp_config/1.20.1-20230612.114412/mcp_config-1.20.1-20230612.114412-mappings-merged.txt, --classes, --reverse-right
# Task: MERGE_MAPPING
# Left:    /workspaces/codespaces-jupyter/Minecraft-server/./libraries/de/oceanlabs/mcp/mcp_config/1.20.1-20230612.114412/mcp_config-1.20.1-20230612.114412-mappings.txt
#          Reversed=false
#          null
# Right:   /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/minecraft/server/1.20.1-20230612.114412/server-1.20.1-20230612.114412-mappings.txt
#          Reversed=true
#          null
# Classes: true
# Fields:  false
# Methods: false
# Params:  false
# Output:  /workspaces/codespaces-jupyter/Minecraft-server/./libraries/de/oceanlabs/mcp/mcp_config/1.20.1-20230612.114412/mcp_config-1.20.1-20230612.114412-mappings-merged.txt
# ===============================================================================
#   Cache:
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/minecraft/server/1.20.1-20230612.114412/server-1.20.1-20230612.114412-slim.jar Validated: 9e06bdd77ca6d95b2cced0bf372245f753eeb16a
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/minecraft/server/1.20.1-20230612.114412/server-1.20.1-20230612.114412-extra.jar Validated: 13522e3278befd103064d91a199451df4cd2633f
#   Cache Hit!
# ===============================================================================
#   MainClass: net.minecraftforge.fart.Main
#   Classpath:
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/minecraftforge/ForgeAutoRenamingTool/0.1.22/ForgeAutoRenamingTool-0.1.22-all.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/sf/jopt-simple/jopt-simple/6.0-alpha-3/jopt-simple-6.0-alpha-3.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/org/ow2/asm/asm-commons/9.2/asm-commons-9.2.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/org/ow2/asm/asm-analysis/9.2/asm-analysis-9.2.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/org/ow2/asm/asm-tree/9.2/asm-tree-9.2.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/org/ow2/asm/asm/9.2/asm-9.2.jar
#     /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/minecraftforge/srgutils/0.4.9/srgutils-0.4.9.jar
#   Args: --input, /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/minecraft/server/1.20.1-20230612.114412/server-1.20.1-20230612.114412-slim.jar, --output, /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/minecraft/server/1.20.1-20230612.114412/server-1.20.1-20230612.114412-srg.jar, --names, /workspaces/codespaces-jupyter/Minecraft-server/./libraries/de/oceanlabs/mcp/mcp_config/1.20.1-20230612.114412/mcp_config-1.20.1-20230612.114412-mappings-merged.txt, --ann-fix, --ids-fix, --src-fix, --record-fix
# Forge Auto Renaming Tool v0.1.22
# log: null
# input: /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/minecraft/server/1.20.1-20230612.114412/server-1.20.1-20230612.114412-slim.jar
# output: /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/minecraft/server/1.20.1-20230612.114412/server-1.20.1-20230612.114412-srg.jar
# threads: 4
# Names: /workspaces/codespaces-jupyter/Minecraft-server/./libraries/de/oceanlabs/mcp/mcp_config/1.20.1-20230612.114412/mcp_config-1.20.1-20230612.114412-mappings-merged.txt(reversed: false)
# Fix Annotations: true
# Fix Records: true
# Fix Identifiers: ALL
# Fix SourceFile: JAVA
# Fix Line Numbers: false
# Strip codesigning signatures: false
# Adding Libraries to Inheritance
# Reading Input: /workspaces/codespaces-jupyter/Minecraft-server/./libraries/net/minecraft/server/1.20.1-20230612.114412/server-1.20.1-20230612.114412-slim.jar
# Adding input to inheritence map
# Processing entries
# Cant Find Class: javax/annotation/Nonnull
# Cant Find Class: org/joml/Matrix3f
# Cant Find Class: javax/annotation/meta/TypeQualifierDefault
# Cant Find Class: org/joml/Vector3f
# Cant Find Class: org/joml/Quaternionf
# Cant Find Class: it/unimi/dsi/fastutil/ints/IntIterator
# Cant Find Class: javax/annotation/Nullable
# Cant Find Class: org/joml/Vector3fc
# Cant Find Class: org/joml/Matrix3fc
# Cant Find Class: it/unimi/dsi/fastutil/booleans/BooleanList
# Cant Find Class: it/unimi/dsi/fastutil/booleans/BooleanArrayList
# Cant Find Class: com/google/common/collect/Maps
# Cant Find Class: com/mojang/datafixers/util/Pair
# Cant Find Class: org/joml/Matrix4f
# Cant Find Class: org/joml/Math
# Cant Find Class: com/google/common/annotations/VisibleForTesting
# Cant Find Class: javax/annotation/ParametersAreNonnullByDefault
# Cant Find Class: com/mojang/serialization/codecs/RecordCodecBuilder$Instance
# Cant Find Class: com/mojang/serialization/codecs/RecordCodecBuilder
# Cant Find Class: com/mojang/datafixers/Products$P4
# Cant Find Class: com/mojang/datafixers/Products
# Cant Find Class: com/mojang/serialization/Codec
# Cant Find Class: org/joml/Matrix4fc
# Cant Find Class: org/apache/commons/lang3/tuple/Triple
# Cant Find Class: org/joml/Quaternionfc
# Cant Find Class: com/mojang/datafixers/util/Either
# Cant Find Class: com/mojang/datafixers/kinds/App
# Cant Find Class: com/mojang/serialization/MapCodec
# Cant Find Class: com/mojang/datafixers/util/Function4
# Cant Find Class: com/mojang/datafixers/kinds/Applicative
# Cant Find Class: com/google/common/collect/Sets
# Cant Find Class: com/mojang/serialization/Keyable
# Cant Find Class: com/google/common/collect/Sets$SetView
# Cant Find Class: org/slf4j/Logger
# Cant Find Class: it/unimi/dsi/fastutil/objects/Object2ObjectOpenHashMap
# Cant Find Class: com/google/common/collect/Multimap
# Cant Find Class: com/google/gson/Gson
# Cant Find Class: com/google/gson/JsonElement
# Cant Find Class: com/mojang/logging/LogUtils
# Cant Find Class: com/google/common/collect/ImmutableSet
# Cant Find Class: com/mojang/brigadier/Message
# Cant Find Class: com/mojang/serialization/DynamicOps
# Cant Find Class: com/mojang/serialization/Encoder
# Cant Find Class: com/google/gson/JsonObject
# Cant Find Class: com/mojang/brigadier/CommandDispatcher
# Cant Find Class: com/mojang/serialization/DataResult
# Cant Find Class: com/google/gson/JsonArray
# Cant Find Class: com/google/common/collect/ImmutableList
# Cant Find Class: com/google/common/collect/UnmodifiableIterator
# Cant Find Class: com/mojang/serialization/JsonOps
# Cant Find Class: com/mojang/brigadier/tree/RootCommandNode
# Cant Find Class: com/mojang/brigadier/tree/CommandNode
# Cant Find Class: com/google/common/collect/BiMap
# Cant Find Class: com/google/common/collect/Lists
# Cant Find Class: com/google/common/base/Stopwatch
# Cant Find Class: com/google/common/collect/ImmutableMap$Builder
# Cant Find Class: com/google/common/collect/ImmutableMap
# Cant Find Class: com/mojang/serialization/Lifecycle
# Cant Find Class: com/google/common/collect/ImmutableList$Builder
# Cant Find Class: com/google/common/hash/HashCode
# Cant Find Class: it/unimi/dsi/fastutil/floats/Float2FloatFunction
# Cant Find Class: com/google/common/hash/HashingOutputStream
# Cant Find Class: com/google/common/hash/Hashing
# Cant Find Class: com/google/common/hash/HashFunction
# Cant Find Class: com/google/gson/stream/JsonWriter
# Cant Find Class: it/unimi/dsi/fastutil/objects/Object2IntOpenHashMap
# Cant Find Class: org/apache/commons/lang3/mutable/MutableInt
# Cant Find Class: org/apache/commons/io/IOUtils
# Cant Find Class: com/mojang/datafixers/DataFixer
# Cant Find Class: com/google/common/collect/Streams
# Cant Find Class: com/google/gson/JsonPrimitive
# Cant Find Class: it/unimi/dsi/fastutil/ints/Int2ObjectOpenHashMap
# Cant Find Class: it/unimi/dsi/fastutil/ints/Int2ObjectMap
# Cant Find Class: it/unimi/dsi/fastutil/objects/Object2IntMap
# Cant Find Class: io/netty/buffer/ByteBuf
# Cant Find Class: it/unimi/dsi/fastutil/objects/Object2IntMaps
# Cant Find Class: it/unimi/dsi/fastutil/objects/Object2IntMap$Entry
# Cant Find Class: org/apache/commons/lang3/StringEscapeUtils
# Cant Find Class: com/google/gson/JsonParseException
# Cant Find Class: org/apache/commons/io/FileUtils
# Cant Find Class: com/google/gson/stream/JsonReader
# Cant Find Class: it/unimi/dsi/fastutil/ints/IntList
# Cant Find Class: com/google/gson/internal/Streams
# Cant Find Class: it/unimi/dsi/fastutil/ints/IntArrayList
# Cant Find Class: it/unimi/dsi/fastutil/ints/IntListIterator
# Cant Find Class: it/unimi/dsi/fastutil/objects/ObjectSet
# Cant Find Class: it/unimi/dsi/fastutil/objects/ObjectIterator
# Cant Find Class: it/unimi/dsi/fastutil/ints/Int2ObjectFunction
# Cant Find Class: com/google/common/escape/Escapers$Builder
# Cant Find Class: com/google/common/escape/Escapers
# Cant Find Class: com/google/common/escape/Escaper
# Cant Find Class: com/mojang/authlib/GameProfile
# Cant Find Class: it/unimi/dsi/fastutil/objects/Object2LongMap$Entry
# Cant Find Class: it/unimi/dsi/fastutil/objects/Object2LongMap
# Cant Find Class: it/unimi/dsi/fastutil/objects/Object2LongOpenHashMap
# Cant Find Class: com/mojang/brigadier/arguments/ArgumentType
# Cant Find Class: com/mojang/brigadier/StringReader
# Cant Find Class: com/mojang/brigadier/exceptions/CommandSyntaxException
# Cant Find Class: com/mojang/brigadier/exceptions/SimpleCommandExceptionType
# Cant Find Class: com/mojang/brigadier/exceptions/CommandExceptionType
# Cant Find Class: com/mojang/brigadier/context/CommandContext
# Cant Find Class: com/mojang/brigadier/suggestion/SuggestionsBuilder
# Cant Find Class: com/mojang/brigadier/suggestion/Suggestions
# Cant Find Class: com/google/common/collect/Iterables
# Cant Find Class: io/netty/channel/SimpleChannelInboundHandler
# Cant Find Class: org/apache/commons/lang3/exception/ExceptionUtils
# Cant Find Class: com/google/common/base/MoreObjects
# Cant Find Class: com/google/gson/JsonDeserializer
# Cant Find Class: com/google/gson/JsonSerializer
# Cant Find Class: com/google/gson/JsonSerializationContext
# Cant Find Class: com/google/gson/JsonDeserializationContext
# Cant Find Class: com/google/gson/JsonSyntaxException
# Cant Find Class: com/mojang/brigadier/builder/LiteralArgumentBuilder
# Cant Find Class: com/mojang/brigadier/Command
# Cant Find Class: com/mojang/brigadier/builder/ArgumentBuilder
# Cant Find Class: com/mojang/brigadier/arguments/BoolArgumentType
# Cant Find Class: com/mojang/brigadier/builder/RequiredArgumentBuilder
# Cant Find Class: com/mojang/brigadier/arguments/IntegerArgumentType
# Cant Find Class: com/mojang/brigadier/arguments/StringArgumentType
# Cant Find Class: com/mojang/brigadier/tree/LiteralCommandNode
# Cant Find Class: com/mojang/authlib/yggdrasil/ServicesKeySet
# Cant Find Class: com/mojang/authlib/minecraft/MinecraftSessionService
# Cant Find Class: com/mojang/authlib/GameProfileRepository
# Cant Find Class: com/google/gson/JsonNull
# Cant Find Class: com/google/gson/GsonBuilder
# Cant Find Class: com/google/common/collect/ImmutableSet$Builder
# Cant Find Class: it/unimi/dsi/fastutil/objects/Object2BooleanMap$Entry
# Cant Find Class: it/unimi/dsi/fastutil/objects/Object2BooleanMap
# Cant Find Class: com/mojang/brigadier/ImmutableStringReader
# Cant Find Class: com/mojang/brigadier/exceptions/BuiltInExceptionProvider
# Cant Find Class: com/mojang/brigadier/exceptions/DynamicCommandExceptionType
# Cant Find Class: org/apache/commons/lang3/ArrayUtils
# Cant Find Class: it/unimi/dsi/fastutil/objects/ObjectArrayList
# Cant Find Class: it/unimi/dsi/fastutil/objects/Object2BooleanOpenHashMap
# Cant Find Class: com/google/common/base/Joiner
# Cant Find Class: com/google/common/collect/ImmutableBiMap$Builder
# Cant Find Class: com/google/common/collect/ImmutableBiMap
# Cant Find Class: com/mojang/serialization/Dynamic
# Cant Find Class: it/unimi/dsi/fastutil/objects/ObjectListIterator
# Cant Find Class: com/mojang/serialization/ListBuilder$Builder
# Cant Find Class: com/mojang/serialization/ListBuilder
# Cant Find Class: com/mojang/serialization/RecordBuilder$MapBuilder
# Cant Find Class: com/mojang/serialization/RecordBuilder
# Cant Find Class: com/mojang/serialization/Decoder
# Cant Find Class: com/mojang/serialization/MapLike
# Cant Find Class: org/apache/commons/lang3/StringUtils
# Cant Find Class: com/mojang/serialization/codecs/PrimitiveCodec
# Cant Find Class: com/google/common/collect/MapMaker
# Cant Find Class: com/mojang/datafixers/Products$P2
# Cant Find Class: org/joml/Vector4f
# Cant Find Class: com/google/gson/JsonParser
# Cant Find Class: com/mojang/datafixers/Products$P1
# Cant Find Class: it/unimi/dsi/fastutil/Hash$Strategy
# Cant Find Class: it/unimi/dsi/fastutil/Hash
# Cant Find Class: it/unimi/dsi/fastutil/objects/ObjectList
# Cant Find Class: it/unimi/dsi/fastutil/objects/Object2IntOpenCustomHashMap
# Cant Find Class: org/apache/commons/lang3/Validate
# Cant Find Class: com/google/common/base/Function
# Cant Find Class: com/google/common/collect/Iterators
# Cant Find Class: com/mojang/datafixers/Products$P3
# Cant Find Class: com/mojang/datafixers/util/Function3
# Cant Find Class: com/mojang/serialization/codecs/UnboundedMapCodec
# Cant Find Class: it/unimi/dsi/fastutil/longs/LongConsumer
# Cant Find Class: com/google/common/collect/AbstractIterator
# Cant Find Class: com/google/common/base/Predicate
# Cant Find Class: org/jetbrains/annotations/Nullable
# Cant Find Class: com/mojang/datafixers/DataFixUtils
# Cant Find Class: javax/annotation/concurrent/Immutable
# Cant Find Class: com/google/common/base/MoreObjects$ToStringHelper
# Cant Find Class: org/jetbrains/annotations/VisibleForTesting
# Cant Find Class: it/unimi/dsi/fastutil/longs/LongOpenHashSet
# Cant Find Class: org/apache/commons/lang3/tuple/Pair
# Cant Find Class: it/unimi/dsi/fastutil/longs/LongSet
# Cant Find Class: com/mojang/util/UUIDTypeAdapter
# Cant Find Class: com/mojang/datafixers/Products$P5
# Cant Find Class: com/mojang/datafixers/util/Function5
# Cant Find Class: io/netty/util/AttributeKey
# Cant Find Class: io/netty/buffer/Unpooled
# Cant Find Class: it/unimi/dsi/fastutil/ints/IntSet
# Cant Find Class: it/unimi/dsi/fastutil/ints/Int2ObjectMaps
# Cant Find Class: com/mojang/brigadier/suggestion/SuggestionProvider
# Cant Find Class: com/mojang/brigadier/tree/ArgumentCommandNode
# Cant Find Class: it/unimi/dsi/fastutil/shorts/ShortSet
# Cant Find Class: it/unimi/dsi/fastutil/shorts/ShortIterator
# Cant Find Class: com/mojang/brigadier/context/StringRange
# Cant Find Class: com/mojang/brigadier/suggestion/Suggestion
# Cant Find Class: it/unimi/dsi/fastutil/ints/IntOpenHashSet
# Cant Find Class: it/unimi/dsi/fastutil/ints/IntSets
# Cant Find Class: it/unimi/dsi/fastutil/ints/IntCollection
# Cant Find Class: it/unimi/dsi/fastutil/ints/IntPredicate
# Cant Find Class: com/google/common/collect/Queues
# Cant Find Class: it/unimi/dsi/fastutil/objects/ObjectIterable
# Cant Find Class: it/unimi/dsi/fastutil/objects/Object2IntFunction
# Cant Find Class: io/netty/handler/codec/ByteToMessageDecoder
# Cant Find Class: io/netty/handler/codec/MessageToByteEncoder
# Cant Find Class: com/mojang/authlib/properties/PropertyMap
# Cant Find Class: io/netty/handler/codec/MessageToMessageDecoder
# Cant Find Class: io/netty/channel/ChannelHandlerContext
# Cant Find Class: io/netty/handler/codec/DecoderException
# Cant Find Class: it/unimi/dsi/fastutil/objects/ObjectOpenHashSet
# Cant Find Class: com/mojang/brigadier/ParseResults
# Cant Find Class: com/mojang/brigadier/context/CommandContextBuilder
# Cant Find Class: com/mojang/brigadier/context/ParsedCommandNode
# Cant Find Class: com/mojang/brigadier/context/ParsedArgument
# Cant Find Class: com/google/common/base/Preconditions
# Cant Find Class: io/netty/channel/Channel
# Cant Find Class: io/netty/util/Attribute
# Cant Find Class: com/google/gson/TypeAdapter
# Cant Find Class: com/google/gson/TypeAdapterFactory
# Cant Find Class: it/unimi/dsi/fastutil/ints/Int2IntFunction
# Cant Find Class: com/google/common/primitives/Longs
# Cant Find Class: com/mojang/datafixers/Products$P8
# Cant Find Class: com/google/common/primitives/Ints
# Cant Find Class: com/mojang/datafixers/util/Function8
# Cant Find Class: io/netty/handler/codec/EncoderException
# Cant Find Class: io/netty/channel/ChannelInitializer
# Cant Find Class: io/netty/channel/ChannelFuture
# Cant Find Class: io/netty/channel/ChannelException
# Cant Find Class: io/netty/channel/ChannelConfig
# Cant Find Class: io/netty/channel/ChannelOption
# Cant Find Class: io/netty/channel/ChannelPipeline
# Cant Find Class: io/netty/handler/timeout/ReadTimeoutHandler
# Cant Find Class: io/netty/channel/ChannelHandler
# Cant Find Class: org/apache/commons/lang3/ObjectUtils
# Cant Find Class: io/netty/handler/codec/MessageToMessageEncoder
# Cant Find Class: it/unimi/dsi/fastutil/objects/ObjectCollection
# Cant Find Class: io/netty/channel/ChannelHandler$Sharable
# Cant Find Class: org/slf4j/Marker
# Cant Find Class: io/netty/channel/nio/NioEventLoopGroup
# Cant Find Class: io/netty/channel/epoll/EpollEventLoopGroup
# Cant Find Class: io/netty/channel/DefaultEventLoopGroup
# Cant Find Class: io/netty/handler/timeout/TimeoutException
# Cant Find Class: io/netty/channel/EventLoop
# Cant Find Class: io/netty/util/concurrent/Future
# Cant Find Class: io/netty/util/concurrent/GenericFutureListener
# Cant Find Class: io/netty/channel/ChannelFutureListener
# Cant Find Class: io/netty/channel/local/LocalChannel
# Cant Find Class: io/netty/channel/local/LocalServerChannel
# Cant Find Class: io/netty/channel/epoll/Epoll
# Cant Find Class: io/netty/channel/epoll/EpollSocketChannel
# Cant Find Class: io/netty/channel/socket/nio/NioSocketChannel
# Cant Find Class: io/netty/bootstrap/Bootstrap
# Cant Find Class: io/netty/channel/EventLoopGroup
# Cant Find Class: io/netty/bootstrap/AbstractBootstrap
# Cant Find Class: it/unimi/dsi/fastutil/ints/IntConsumer
# Cant Find Class: io/netty/handler/codec/CorruptedFrameException
# Cant Find Class: io/netty/buffer/ByteBufOutputStream
# Cant Find Class: io/netty/buffer/ByteBufInputStream
# Cant Find Class: com/mojang/authlib/properties/Property
# Cant Find Class: io/netty/buffer/ByteBufAllocator
# Cant Find Class: io/netty/channel/socket/SocketChannel
# Cant Find Class: io/netty/util/ResourceLeakDetector$Level
# Cant Find Class: com/google/common/util/concurrent/ThreadFactoryBuilder
# Cant Find Class: org/slf4j/MarkerFactory
# Cant Find Class: io/netty/util/ResourceLeakDetector
# Cant Find Class: com/mojang/datafixers/DSL$TypeReference
# Cant Find Class: com/mojang/datafixers/DSL
# Cant Find Class: it/unimi/dsi/fastutil/ints/IntStack
# Cant Find Class: io/netty/util/ByteProcessor
# Cant Find Class: io/netty/util/ReferenceCounted
# Cant Find Class: org/apache/commons/lang3/mutable/MutableObject
# Cant Find Class: it/unimi/dsi/fastutil/objects/Object2FloatMap
# Cant Find Class: it/unimi/dsi/fastutil/objects/Object2FloatOpenCustomHashMap
# Cant Find Class: it/unimi/dsi/fastutil/objects/Object2FloatMaps
# Cant Find Class: com/google/common/collect/ImmutableCollection
# Cant Find Class: com/google/gson/JsonIOException
# Unexpected lack of synthetic args to the constructor: expected [Lnet/minecraft/util/ExtraCodecs;] at the start of <init>(Ljava/util/function/Function;)V in net/minecraft/util/ExtraCodecs$1ContextRetrievalCodec
# Cant Find Class: com/google/gson/reflect/TypeToken
# Cant Find Class: org/apache/commons/lang3/math/NumberUtils
# Cant Find Class: com/google/gson/stream/JsonToken
# Cant Find Class: com/mojang/authlib/yggdrasil/ServicesKeyType
# Cant Find Class: com/mojang/authlib/yggdrasil/ServicesKeyInfo
# Cant Find Class: it/unimi/dsi/fastutil/objects/ObjectArrays
# Cant Find Class: it/unimi/dsi/fastutil/floats/FloatList
# Cant Find Class: it/unimi/dsi/fastutil/floats/FloatArrayList
# Cant Find Class: com/mojang/serialization/Codec$ResultFunction
# Cant Find Class: org/joml/AxisAngle4f
# Cant Find Class: com/sun/jna/platform/win32/Tlhelp32$MODULEENTRY32W
# Cant Find Class: com/sun/jna/platform/win32/Tlhelp32
# Cant Find Class: com/sun/jna/Platform
# Cant Find Class: com/sun/jna/platform/win32/Kernel32
# Cant Find Class: com/sun/jna/platform/win32/Kernel32Util
# Cant Find Class: com/sun/jna/ptr/IntByReference
# Cant Find Class: com/sun/jna/platform/win32/Version
# Cant Find Class: com/sun/jna/Native
# Cant Find Class: com/sun/jna/platform/win32/Win32Exception
# Cant Find Class: com/sun/jna/Memory
# Cant Find Class: com/sun/jna/Pointer
# Cant Find Class: com/sun/jna/ptr/PointerByReference
# Cant Find Class: com/google/common/base/Supplier
# Cant Find Class: com/google/common/base/Suppliers
# Cant Find Class: com/mojang/datafixers/DataFix
# Cant Find Class: com/mojang/datafixers/types/templates/TaggedChoice$TaggedChoiceType
# Cant Find Class: com/mojang/datafixers/types/templates/TaggedChoice
# Cant Find Class: com/mojang/datafixers/schemas/Schema
# Cant Find Class: com/mojang/datafixers/TypeRewriteRule
# Cant Find Class: com/mojang/datafixers/types/Type
# Cant Find Class: com/mojang/datafixers/Typed
# Cant Find Class: com/mojang/datafixers/OpticFinder
# Cant Find Class: com/mojang/serialization/OptionalDynamic
# Cant Find Class: com/mojang/serialization/DynamicLike
# Cant Find Class: org/jetbrains/annotations/Contract
# Cant Find Class: com/mojang/datafixers/types/templates/Tag$TagType
# Cant Find Class: com/mojang/datafixers/types/templates/Tag
# Cant Find Class: com/mojang/datafixers/types/templates/List$ListType
# Cant Find Class: com/mojang/datafixers/types/templates/List
# Cant Find Class: com/mojang/datafixers/types/templates/CompoundList$CompoundListType
# Cant Find Class: com/mojang/datafixers/types/templates/CompoundList
# Cant Find Class: com/mojang/datafixers/util/Unit
# Cant Find Class: com/mojang/datafixers/FieldFinder
# Cant Find Class: it/unimi/dsi/fastutil/ints/Int2IntMap
# Cant Find Class: it/unimi/dsi/fastutil/ints/Int2IntOpenHashMap
# Cant Find Class: com/google/common/base/Splitter
# Cant Find Class: it/unimi/dsi/fastutil/ints/Int2ObjectMap$Entry
# Cant Find Class: it/unimi/dsi/fastutil/ints/Int2ObjectLinkedOpenHashMap
# Cant Find Class: org/apache/commons/lang3/mutable/MutableBoolean
# Cant Find Class: it/unimi/dsi/fastutil/ints/Int2IntLinkedOpenHashMap
# Cant Find Class: it/unimi/dsi/fastutil/shorts/ShortArrayList
# Cant Find Class: it/unimi/dsi/fastutil/shorts/ShortList
# Cant Find Class: it/unimi/dsi/fastutil/ints/Int2ObjectArrayMap
# Cant Find Class: it/unimi/dsi/fastutil/objects/Object2IntMap$FastEntrySet
# Cant Find Class: it/unimi/dsi/fastutil/objects/Object2IntArrayMap
# Cant Find Class: it/unimi/dsi/fastutil/ints/IntBinaryOperator
# Cant Find Class: com/google/common/collect/Streams$IntFunctionWithIndex
# Cant Find Class: com/mojang/datafixers/DataFixerBuilder
# Cant Find Class: com/mojang/datafixers/types/templates/TypeTemplate
# Cant Find Class: com/mojang/datafixers/types/templates/Hook$HookFunction
# Cant Find Class: com/mojang/datafixers/types/templates/Hook
# Cant Find Class: com/mojang/datafixers/types/templates/Const$PrimitiveType
# Cant Find Class: com/mojang/datafixers/types/templates/Const
# Cant Find Class: com/google/common/base/Predicates
# Cant Find Class: com/google/common/util/concurrent/ListeningExecutorService
# Cant Find Class: com/google/common/util/concurrent/MoreExecutors
# Cant Find Class: it/unimi/dsi/fastutil/ints/Int2BooleanFunction
# Cant Find Class: com/google/common/collect/HashMultimap
# Cant Find Class: com/google/common/base/Charsets
# Cant Find Class: it/unimi/dsi/fastutil/ints/Int2DoubleMap
# Cant Find Class: com/google/common/base/Ticker
# Cant Find Class: oshi/SystemInfo
# Cant Find Class: oshi/hardware/CentralProcessor
# Cant Find Class: oshi/hardware/HardwareAbstractionLayer
# Cant Find Class: it/unimi/dsi/fastutil/ints/Int2DoubleOpenHashMap
# Cant Find Class: com/google/gson/LongSerializationPolicy
# Cant Find Class: com/google/common/math/Quantiles$ScaleAndIndexes
# Cant Find Class: com/google/common/math/Quantiles
# Cant Find Class: com/google/common/math/Quantiles$Scale
# Cant Find Class: it/unimi/dsi/fastutil/ints/Int2DoubleRBTreeMap
# Cant Find Class: it/unimi/dsi/fastutil/ints/Int2DoubleSortedMap
# Cant Find Class: it/unimi/dsi/fastutil/ints/Int2DoubleSortedMaps
# Cant Find Class: it/unimi/dsi/fastutil/objects/Object2LongMaps
# Cant Find Class: it/unimi/dsi/fastutil/bytes/ByteArrays
# Cant Find Class: it/unimi/dsi/fastutil/longs/LongList
# Cant Find Class: it/unimi/dsi/fastutil/longs/LongArrayList
# Cant Find Class: it/unimi/dsi/fastutil/objects/ObjectArraySet
# Cant Find Class: io/netty/util/internal/ThreadLocalRandom
# Cant Find Class: com/google/common/collect/Interner
# Cant Find Class: com/google/common/collect/Interners
# Cant Find Class: com/mojang/serialization/DataResult$PartialResult
# Cant Find Class: it/unimi/dsi/fastutil/HashCommon
# Cant Find Class: org/apache/commons/io/FilenameUtils
# Cant Find Class: it/unimi/dsi/fastutil/ints/IntAVLTreeSet
# Cant Find Class: it/unimi/dsi/fastutil/longs/Long2LongMap$Entry
# Cant Find Class: it/unimi/dsi/fastutil/longs/Long2LongMap
# Cant Find Class: it/unimi/dsi/fastutil/longs/Long2LongOpenHashMap
# Cant Find Class: it/unimi/dsi/fastutil/shorts/Short2ObjectMap
# Cant Find Class: it/unimi/dsi/fastutil/longs/Long2ByteMap
# Cant Find Class: it/unimi/dsi/fastutil/longs/Long2ByteOpenHashMap
# Cant Find Class: it/unimi/dsi/fastutil/shorts/Short2ObjectOpenHashMap
# Cant Find Class: it/unimi/dsi/fastutil/shorts/Short2ObjectFunction
# Cant Find Class: org/apache/commons/lang3/mutable/MutableLong
# Cant Find Class: com/mojang/datafixers/kinds/OptionalBox$Mu
# Cant Find Class: com/mojang/datafixers/kinds/OptionalBox
# Cant Find Class: com/mojang/datafixers/kinds/K1
# Cant Find Class: com/mojang/datafixers/kinds/Applicative$Mu
# Cant Find Class: com/mojang/datafixers/kinds/IdF$Mu
# Cant Find Class: com/mojang/datafixers/kinds/IdF
# Cant Find Class: com/mojang/datafixers/kinds/Const$Mu
# Cant Find Class: com/mojang/datafixers/kinds/Const
# Cant Find Class: com/mojang/datafixers/Products$P7
# Cant Find Class: com/mojang/datafixers/util/Function7
# Cant Find Class: it/unimi/dsi/fastutil/longs/Long2ObjectMap$Entry
# Cant Find Class: it/unimi/dsi/fastutil/longs/Long2ObjectMap
# Cant Find Class: it/unimi/dsi/fastutil/longs/Long2ObjectOpenHashMap
# Cant Find Class: it/unimi/dsi/fastutil/longs/Long2ObjectFunction
# Cant Find Class: it/unimi/dsi/fastutil/objects/Object2ObjectArrayMap
# Cant Find Class: it/unimi/dsi/fastutil/objects/Object2DoubleMap
# Cant Find Class: it/unimi/dsi/fastutil/objects/Object2DoubleArrayMap
# Cant Find Class: it/unimi/dsi/fastutil/ints/Int2ObjectAVLTreeMap
# Cant Find Class: it/unimi/dsi/fastutil/ints/Int2ObjectSortedMap
# Found extra RuntimeVisibleParameterAnnotations entries in <init>(Lnet/minecraft/world/entity/animal/Fox;Ljava/lang/Class;ZZLjava/util/function/Predicate;)V in net/minecraft/world/entity/animal/Fox$DefendTrustedTargetGoal: removing 1
# Cant Find Class: com/google/common/base/Objects
# Cant Find Class: it/unimi/dsi/fastutil/doubles/DoubleList
# Cant Find Class: it/unimi/dsi/fastutil/doubles/AbstractDoubleList
# Cant Find Class: it/unimi/dsi/fastutil/doubles/DoubleArrayList
# Cant Find Class: com/google/common/math/IntMath
# Cant Find Class: com/google/common/math/DoubleMath
# Cant Find Class: it/unimi/dsi/fastutil/doubles/DoubleLists
# Cant Find Class: com/google/common/collect/LinkedHashMultiset
# Cant Find Class: com/google/common/collect/Multiset
# Cant Find Class: com/google/common/collect/Multisets
# Cant Find Class: com/google/common/collect/ImmutableMultiset
# Cant Find Class: it/unimi/dsi/fastutil/ints/IntComparators
# Cant Find Class: it/unimi/dsi/fastutil/ints/IntComparator
# Cant Find Class: it/unimi/dsi/fastutil/objects/ObjectLinkedOpenCustomHashSet
# Cant Find Class: com/google/common/collect/ImmutableMultimap$Builder
# Cant Find Class: com/google/common/collect/ImmutableMultimap
# Cant Find Class: org/apache/commons/lang3/mutable/MutableFloat
# Cant Find Class: com/google/common/collect/HashBasedTable
# Cant Find Class: com/google/common/collect/Table
# Cant Find Class: it/unimi/dsi/fastutil/objects/ObjectOpenCustomHashSet
# Cant Find Class: it/unimi/dsi/fastutil/longs/Long2LongMaps
# Cant Find Class: com/mojang/brigadier/ResultConsumer
# Cant Find Class: it/unimi/dsi/fastutil/longs/LongIterator
# Cant Find Class: com/google/common/collect/HashBiMap
# Cant Find Class: com/google/common/io/Files
# Cant Find Class: com/google/common/io/ByteSource
# Cant Find Class: it/unimi/dsi/fastutil/objects/Object2FloatOpenHashMap
# ...
#   Patching net/minecraft/client/renderer/entity/ItemEntityRenderer 1/1
#   Patching net/minecraft/client/gui/screens/packs/PackSelectionModel 1/1
#   Patching net/minecraft/client/renderer/block/model/ItemModelGenerator$SpanFacing 1/1
#   Patching net/minecraft/client/gui/screens/worldselection/CreateWorldScreen$GameTab 1/1
#   Patching net/minecraft/client/renderer/block/model/BlockModel$Deserializer 1/1
#   Patching net/minecraft/client/renderer/entity/EntityRenderer 1/1
#   Patching net/minecraft/client/renderer/texture/SpriteContents$FrameInfo 1/1
#   Patching net/minecraft/client/gui/screens/Screen$DeferredTooltipRendering 1/1
#   Patching net/minecraft/client/particle/PortalParticle 1/1
#   Patching net/minecraft/client/multiplayer/ClientChunkCache$Storage 1/1
#   Patching net/minecraft/client/gui/components/DebugScreenOverlay 1/1
#   Patching net/minecraft/client/Minecraft$ChatStatus$1 1/1
#   Patching net/minecraft/client/renderer/entity/LivingEntityRenderer$1 1/1
#   Patching net/minecraft/client/Minecraft$ChatStatus$2 1/1
#   Patching net/minecraft/client/multiplayer/ServerStatusPinger$1 1/1
#   Patching net/minecraft/client/multiplayer/ClientLevel$EntityCallbacks 1/1
#   Patching net/minecraft/client/multiplayer/ServerStatusPinger$2 1/1
#   Patching net/minecraft/client/renderer/texture/TextureAtlasSprite$1 1/1
#   Patching net/minecraft/client/renderer/LevelRenderer$RenderChunkInfo 1/1
#   Patching net/minecraft/client/gui/components/Button$CreateNarration 1/1
#   Patching net/minecraft/client/server/IntegratedServer 1/1
#   Patching net/minecraft/client/resources/model/MultiPartBakedModel$Builder 1/1
#   Patching net/minecraft/client/renderer/FogRenderer 1/1
#   Patching net/minecraft/client/renderer/texture/SpriteContents$InterpolationData 1/1
#   Patching net/minecraft/client/renderer/block/LiquidBlockRenderer$1 1/1
#   Patching net/minecraft/client/renderer/chunk/RenderChunkRegion 1/1
#   Patching net/minecraft/client/renderer/block/BlockRenderDispatcher 1/1
#   Patching net/minecraft/client/resources/model/ModelManager 1/1
#   Patching net/minecraft/client/renderer/block/model/ItemModelGenerator$Span 1/1
#   Patching net/minecraft/client/renderer/ItemInHandRenderer 1/1
#   Patching net/minecraft/client/renderer/block/LiquidBlockRenderer 1/1
#   Patching net/minecraft/client/gui/Font 1/1
#   Patching net/minecraft/client/particle/BreakingItemParticle$SnowballProvider 1/1
#   Patching net/minecraft/client/resources/language/LanguageManager 1/1
#   Patching com/mojang/blaze3d/platform/GlStateManager$ScissorState 1/1
#   Patching net/minecraft/client/renderer/entity/LivingEntityRenderer 1/1
#   Patching net/minecraft/client/multiplayer/ClientChunkCache 1/1
#   Patching net/minecraft/client/renderer/PostChain 1/1
#   Patching net/minecraft/client/gui/screens/worldselection/WorldSelectionList$Entry 1/1
#   Patching net/minecraft/client/renderer/Sheets 1/1
#   Patching net/minecraft/client/gui/components/DebugScreenOverlay$AllocationRateCalculator 1/1
#   Patching net/minecraft/client/particle/EnchantmentTableParticle 1/1
#   Patching net/minecraft/client/renderer/entity/player/PlayerRenderer 1/1
#   Patching com/mojang/blaze3d/vertex/VertexFormat$IndexType 1/1
#   Patching net/minecraft/client/gui/components/Button 1/1
#   Patching net/minecraft/client/renderer/block/model/BlockModel$LoopException 1/1
#   Patching com/mojang/realmsclient/gui/screens/RealmsGenericErrorScreen$ErrorMessage 1/1
#   Patching net/minecraft/client/model/HumanoidModel$ArmPose 1/1
#   Patching net/minecraft/client/renderer/block/ModelBlockRenderer$SizeInfo 1/1
#   Patching net/minecraft/client/renderer/texture/SpriteLoader 1/1
#   Patching net/minecraft/client/renderer/RenderType$CompositeState$CompositeStateBuilder 1/1
#   Patching net/minecraft/client/renderer/ItemInHandRenderer$HandRenderSelection 1/1
#   Patching net/minecraft/client/renderer/block/ModelBlockRenderer 1/1
#   Patching com/mojang/blaze3d/platform/GlStateManager$TextureState 1/1
#   Patching net/minecraft/client/ClientBrandRetriever 1/1
#   Patching net/minecraft/client/gui/MapRenderer$MapInstance 1/1
#   Patching net/minecraft/client/renderer/block/model/ItemOverrides 1/1
#   Patching net/minecraft/client/gui/Gui$HeartType 1/1
#   Patching net/minecraft/client/renderer/entity/layers/ElytraLayer 1/1
#   Patching net/minecraft/client/gui/screens/Screen 1/1
#   Patching net/minecraft/client/gui/screens/inventory/HangingSignEditScreen 1/1
#   Patching net/minecraft/client/particle/TerrainParticle 1/1
#   Patching com/mojang/blaze3d/vertex/VertexFormatElement$Usage$ClearState 1/1
#   Patching com/mojang/blaze3d/vertex/BufferBuilder$DrawState 1/1
#   Patching com/mojang/blaze3d/platform/GlStateManager$ColorMask 1/1
#   Patching com/mojang/realmsclient/gui/screens/RealmsNotificationsScreen$3 1/1
#   Patching com/mojang/blaze3d/platform/Window 1/1
#   Patching com/mojang/realmsclient/gui/screens/RealmsNotificationsScreen$1 1/1
#   Patching net/minecraft/client/gui/screens/worldselection/WorldSelectionList$LoadingHeader 1/1
#   Patching com/mojang/realmsclient/gui/screens/RealmsNotificationsScreen$2 1/1
#   Patching net/minecraft/client/renderer/block/model/ItemTransform 1/1
#   Patching net/minecraft/client/gui/components/BossHealthOverlay 1/1
#   Patching net/minecraft/client/renderer/ItemModelShaper 1/1
#   Patching net/minecraft/client/player/RemotePlayer 1/1
#   Patching net/minecraft/client/main/Main 1/1
#   Patching net/minecraft/client/renderer/chunk/ChunkRenderDispatcher$RenderChunk$ResortTransparencyTask 1/1
#   Patching net/minecraft/client/gui/screens/Screen$NarratableSearchResult 1/1
#   Patching net/minecraft/client/resources/model/BakedModel 1/1
#   Patching com/mojang/realmsclient/gui/screens/RealmsNotificationsScreen 1/1
#   Patching net/minecraft/world/level/biome/BiomeSpecialEffects$GrassColorModifier$ColorModifier 1/1
#   Patching net/minecraft/client/renderer/LevelRenderer 1/1
#   Patching net/minecraft/client/gui/screens/controls/KeyBindsList 1/1
#   Patching net/minecraft/client/renderer/DimensionSpecialEffects$OverworldEffects 1/1
#   Patching net/minecraft/client/gui/components/AbstractSelectionList$TrackedList 1/1
#   Patching net/minecraft/client/renderer/EffectInstance 1/1
#   Patching net/minecraft/client/renderer/SpriteCoordinateExpander 1/1
#   Patching net/minecraft/client/particle/ParticleEngine$1ParticleDefinition 1/1
#   Patching net/minecraft/Util$3 1/1
#   Patching net/minecraft/Util$4 1/1
#   Patching net/minecraft/client/multiplayer/ClientPacketListener 1/1
#   Patching net/minecraft/client/gui/screens/worldselection/PresetEditor 1/1
#   Patching net/minecraft/client/renderer/DimensionSpecialEffects$EndEffects 1/1
#   Patching net/minecraft/client/particle/FireworkParticles$OverlayParticle 1/1
#   Patching net/minecraft/client/gui/screens/inventory/InventoryScreen 1/1
#   Patching net/minecraft/client/gui/screens/advancements/AdvancementsScreen 1/1
#   Patching com/mojang/blaze3d/pipeline/RenderTarget 1/1
#   Patching com/mojang/blaze3d/vertex/VertexFormat 1/1
#   Patching net/minecraft/client/gui/screens/worldselection/WorldSelectionList$WorldListEntry 1/1
#   Patching net/minecraft/client/gui/screens/worldselection/WorldCreationUiState$SelectedGameMode 1/1
#   Patching net/minecraft/client/server/LanServerDetection$LanServerDetector 1/1
#   Patching net/minecraft/client/sounds/SoundEngine 1/1
#   Patching net/minecraft/client/particle/FireworkParticles$1 1/1
#   Patching net/minecraft/client/renderer/FogRenderer$BlindnessFogFunction 1/1
#   Patching com/mojang/blaze3d/platform/GlStateManager$DepthState 1/1
#   Patching net/minecraft/client/multiplayer/ServerData 1/1
#   Patching net/minecraft/client/renderer/texture/TextureAtlas 1/1
#   Patching net/minecraft/client/renderer/block/model/ItemModelGenerator$1 1/1
#   Patching net/minecraft/client/particle/VibrationSignalParticle 1/1
#   Patching net/minecraft/client/renderer/ItemInHandRenderer$1 1/1
#   Patching net/minecraft/client/gui/Font$DisplayMode 1/1
#   Patching net/minecraft/client/gui/screens/LoadingOverlay 1/1
#   Patching net/minecraft/client/particle/BreakingItemParticle$SlimeProvider 1/1
#   Patching net/minecraft/client/model/HumanoidModel$1 1/1
#   Patching net/minecraft/client/renderer/entity/ItemFrameRenderer 1/1
#   Patching net/minecraft/client/renderer/FogRenderer$FogMode 1/1
#   Patching net/minecraft/client/gui/screens/worldselection/WorldSelectionList 1/1
#   Patching com/mojang/blaze3d/platform/GlStateManager$Viewport 1/1
#   Patching net/minecraft/client/resources/model/WeightedBakedModel 1/1
#   Patching net/minecraft/client/renderer/ShaderInstance 1/1
#   Patching net/minecraft/client/Minecraft 1/1
#   Patching net/minecraft/client/ToggleKeyMapping 1/1
#   Patching net/minecraft/client/renderer/RenderType$CompositeRenderType 1/1
#   Patching net/minecraft/client/renderer/chunk/ChunkRenderDispatcher$ChunkTaskResult 1/1
#   Patching net/minecraft/client/renderer/block/model/ItemTransforms$1 1/1
#   Patching net/minecraft/client/renderer/entity/FishingHookRenderer 1/1
#   Patching net/minecraft/client/gui/screens/ConnectScreen 1/1
#   Patching net/minecraft/client/renderer/blockentity/SkullBlockRenderer 1/1
#   Patching net/minecraft/client/multiplayer/ClientPacketListener$DeferredPacket 1/1
#   Patching net/minecraft/client/server/LanServerDetection$LanServerList 1/1
#   Patching net/minecraft/client/renderer/block/ModelBlockRenderer$AmbientVertexRemap 1/1
#   Patching net/minecraft/client/resources/model/ModelBakery$LoadedJson 1/1
#   Patching net/minecraft/client/particle/ParticleEngine 1/1
#   Patching net/minecraft/client/renderer/block/model/BakedQuad 1/1
#   Patching net/minecraft/client/particle/ReversePortalParticle$ReversePortalProvider 1/1
#   Patching com/mojang/blaze3d/platform/GlStateManager$ColorLogicState 1/1
#   Patching net/minecraft/client/gui/screens/advancements/AdvancementTabType 1/1
#   Patching net/minecraft/client/gui/screens/packs/PackSelectionModel$EntryBase 1/1
#   Patching net/minecraft/client/gui/screens/worldselection/WorldCreationUiState$WorldTypeEntry 1/1
#   Patching net/minecraft/client/renderer/entity/EntityRenderDispatcher 1/1
#   Patching net/minecraft/client/renderer/block/model/ItemOverrides$PropertyMatcher 1/1
#   Patching net/minecraft/client/particle/EnchantmentTableParticle$Provider 1/1
#   Patching net/minecraft/client/gui/GuiGraphics 1/1
#   Patching net/minecraft/world/item/Items$1 1/1
#   Patching net/minecraft/client/gui/components/toasts/ToastComponent$ToastInstance 1/1
#   Patching net/minecraft/client/renderer/chunk/ChunkRenderDispatcher 1/1
#   Patching net/minecraft/client/particle/BreakingItemParticle$Provider 1/1
#   Patching net/minecraft/client/gui/screens/ChatScreen$1 1/1
#   Patching net/minecraft/client/multiplayer/chat/ChatListener$Message 1/1
#   Patching net/minecraft/client/gui/components/DebugScreenOverlay$1 1/1
#   Patching net/minecraft/client/renderer/block/model/BlockModel$GuiLight 1/1
#   Patching net/minecraft/client/gui/screens/inventory/tooltip/ClientTooltipComponent 1/1
#   Patching net/minecraft/client/renderer/texture/Stitcher$Holder 1/1
#   Patching net/minecraft/client/Screenshot 1/1
#   Patching com/mojang/blaze3d/vertex/SheetedDecalTextureGenerator 1/1
#   Patching net/minecraft/client/User$Type 1/1
#   Patching com/mojang/blaze3d/vertex/BufferBuilder 1/1
#   Patching com/mojang/realmsclient/gui/screens/RealmsGenericErrorScreen 1/1
#   Patching net/minecraft/client/gui/screens/OptionsScreen 1/1
#   Patching net/minecraft/client/RecipeBookCategories 1/1
#   Patching com/mojang/blaze3d/vertex/VertexFormat$1 1/1
#   Patching net/minecraft/client/renderer/LevelRenderer$RenderChunkStorage 1/1
#   Patching net/minecraft/client/gui/screens/packs/PackSelectionModel$UnselectedPackEntry 1/1
#   Patching net/minecraft/client/resources/model/ModelBakery$BakedCacheKey 1/1
#   Patching net/minecraft/client/renderer/block/ModelBlockRenderer$1 1/1
#   Patching net/minecraft/client/particle/FireworkParticles 1/1
#   Patching net/minecraft/client/renderer/block/model/FaceBakery 1/1
#   Patching com/mojang/blaze3d/platform/GlStateManager$LogicOp 1/1
#   Patching net/minecraft/client/gui/screens/inventory/CreativeModeInventoryScreen 1/1
#   Patching net/minecraft/client/resources/language/I18n 1/1
#   Patching net/minecraft/client/gui/screens/advancements/AdvancementTabType$1 1/1
#   Patching net/minecraft/client/renderer/block/model/BlockElementFace$Deserializer 1/1
#   Patching net/minecraft/client/gui/components/AbstractWidget 1/1
#   Patching net/minecraft/client/renderer/DimensionSpecialEffects$SkyType 1/1
#   Patching net/minecraft/client/gui/screens/LoadingOverlay$LogoTexture 1/1
#   Patching net/minecraft/client/gui/screens/multiplayer/JoinMultiplayerScreen 1/1
#   Patching net/minecraft/client/renderer/block/BlockRenderDispatcher$1 1/1
#   Patching net/minecraft/client/particle/ParticleEngine$SpriteParticleRegistration 1/1
#   Patching net/minecraft/client/gui/screens/controls/KeyBindsList$CategoryEntry 1/1
#   Patching net/minecraft/client/gui/screens/worldselection/WorldOpenFlows$1Data 1/1
#   Patching net/minecraft/client/player/AbstractClientPlayer 1/1
#   Patching net/minecraft/client/gui/screens/advancements/AdvancementTab 1/1
#   Patching net/minecraft/client/KeyboardHandler 1/1
#   Patching net/minecraft/client/renderer/entity/BoatRenderer 1/1
#   Patching net/minecraft/client/gui/screens/MenuScreens$ScreenConstructor 1/1
#   Patching net/minecraft/client/multiplayer/ClientLevel$ClientLevelData 1/1
#   Patching net/minecraft/client/gui/components/AbstractSelectionList$1 1/1
#   Patching net/minecraft/client/renderer/chunk/ChunkRenderDispatcher$RenderChunk$ChunkCompileTask 1/1
#   Patching net/minecraft/client/gui/screens/inventory/CreativeModeInventoryScreen$CustomCreativeSlot 1/1
#   Patching net/minecraft/client/multiplayer/ServerStatusPinger$2$1 1/1
#   Patching com/mojang/blaze3d/vertex/VertexFormatElement$Usage 1/1
#   Patching net/minecraft/client/renderer/block/ModelBlockRenderer$AmbientOcclusionFace 1/1
#   Patching net/minecraft/client/multiplayer/ClientHandshakePacketListenerImpl 1/1
#   Patching net/minecraft/client/multiplayer/ClientPacketListener$1 1/1
#   Patching net/minecraft/client/particle/ParticleEngine$MutableSpriteSet 1/1
#   Patching net/minecraft/client/color/item/ItemColors 1/1
#   Patching net/minecraft/client/gui/screens/controls/KeyBindsList$CategoryEntry$1 1/1
#   Patching net/minecraft/client/particle/ReversePortalParticle 1/1
#   Patching net/minecraft/client/renderer/block/model/ItemTransform$Deserializer 1/1
#   Patching com/mojang/blaze3d/vertex/BufferBuilder$SortState 1/1
#   Patching net/minecraft/client/renderer/texture/SpriteContents$Ticker 1/1
#   Patching net/minecraft/client/gui/screens/worldselection/CreateWorldScreen$DataPackReloadCookie 1/1
#   Patching net/minecraft/client/gui/GuiGraphics$ScissorStack 1/1
#   Patching net/minecraft/client/gui/screens/packs/PackSelectionModel$SelectedPackEntry 1/1
#   Patching net/minecraft/client/renderer/chunk/ChunkRenderDispatcher$RenderChunk$RebuildTask 1/1
#   Patching net/minecraft/client/renderer/texture/MipmapGenerator 1/1
#   Patching net/minecraft/client/renderer/block/model/BlockElement$Deserializer 1/1
#   Patching net/minecraft/client/renderer/ScreenEffectRenderer 1/1
#   Patching net/minecraft/client/gui/screens/MenuScreens 1/1
#   Patching net/minecraft/client/gui/screens/TitleScreen 1/1
#   Patching net/minecraft/client/main/Main$2 1/1
#   Patching net/minecraft/client/main/Main$1 1/1
#   Patching net/minecraft/client/gui/screens/worldselection/WorldCreationUiState 1/1
#   Patching net/minecraft/client/server/LanServerPinger 1/1
#   Patching net/minecraft/client/main/Main$3 1/1
#   Patching net/minecraft/client/particle/BreakingItemParticle 1/1
#   Patching net/minecraft/client/resources/model/SimpleBakedModel 1/1
#   Patching com/mojang/blaze3d/platform/GlStateManager 1/1
#   Patching net/minecraft/client/multiplayer/MultiPlayerGameMode 1/1
#   Patching net/minecraft/client/gui/screens/inventory/CreativeModeInventoryScreen$ItemPickerMenu 1/1
#   Patching net/minecraft/client/renderer/entity/ItemRenderer 1/1
#   Patching com/mojang/blaze3d/vertex/VertexFormatElement$Usage$SetupState 1/1
# The server installed successfully
# You can delete this installer file now if you wish
# Completado!

# %%
#Tienes que poner el spawn proteccion en 0 para que puedas jugar de manera normal(esto dentro de Server.properties)
#importa librerias necesarias para ejecucion

import requests

import time

import os

import re

import json

import glob

import threading

import subprocess


#Actualizacion de lista de paquetes

# !sudo apt update &>/dev/null && echo "el apt cache fue actualizado correctamente" || echo "la actualizacion del apt cache fallo, es posible que recibas paquetes obsoletos"

#Asignar archivos al directorio


os.makedirs("/workspaces/codespaces-jupyter/Minecraft-server", exist_ok=True)

os.chdir("/workspaces/codespaces-jupyter/Minecraft-server")

# !ls #lista los archivos del directorio para verificarlos



#Importacion del archivo de configuracion


config_path = "/workspaces/codespaces-jupyter/Minecraft-server/colabconfig.json"

if os.path.isfile(config_path):

    with open(config_path) as config_file:

        colabconfig = json.load(config_file)

else:

    colabconfig = {"server_type": "generic"} # Usar la configura default si no existe

    with open(config_path, 'w') as new_config_file:

        json.dump(colabconfig, new_config_file)

# Instalar OpenJDK

version = colabconfig["server_version"]

# Ejecuta un comando en la terminal

def ejecutar_comando(comando):
    proceso = subprocess.run(comando, shell=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

    # Comprueba si el comando se ejecutó con éxito
    if proceso.returncode == 0:
        print("OpenJDK 17 instalado correctamente")
    else:
        print("Fallo al instalar OpenJDK 17")

# Purga versiones anteriores de OpenJDK
ejecutar_comando('sudo apt-get purge openjdk* -y')

# Instala OpenJDK 17
ejecutar_comando('sudo apt-get install openjdk-17-jre-headless -y')

# Chequeo de version de java

java_ver = !java -version 2>&1 | awk -F[\"\.] -v OFS=. 'NR==1{print $2}'

#Lista de posibles archivos .jar

jar_list = {'paper': 'paper.jar', 'fabric': 'fabric-server-launch.jar', 'generic': 'server.jar', 'forge': 'forge.jar', 'vanilla': 'vanilla.jar', 'snapshot': 'snapshot.jar', 'mohist': "mohist.jar", 'catserver': "catserver.jar", 'purpur': "purpur.jar"}

jar_name = jar_list[colabconfig["server_type"]]

# Argumentos de java.

if colabconfig["server_type"] == "paper":

    server_flags = "-XX:+UseG1GC -XX:+ParallelRefProcEnabled -XX:MaxGCPauseMillis=200 -XX:+UnlockExperimentalVMOptions -XX:+DisableExplicitGC -XX:+AlwaysPreTouch -XX:G1NewSizePercent=30 -XX:G1MaxNewSizePercent=40 -XX:G1HeapRegionSize=8M -XX:G1ReservePercent=20 -XX:G1HeapWastePercent=5 -XX:G1MixedGCCountTarget=4 -XX:InitiatingHeapOccupancyPercent=15 -XX:G1MixedGCLiveThresholdPercent=90 -XX:G1RSetUpdatingPauseTimePercent=5 -XX:SurvivorRatio=32 -XX:+PerfDisableSharedMem -XX:MaxTenuringThreshold=1 -Dusing.aikars.flags=https://mcflags.emc.gs -Daikars.new.flags=true"

else:

    server_flags = "" # No se necesitan banderas para servidores que no sean de paper

#Argumentos JVM

memory_allocation = "-Xms10G -Xmx10G"



# Elige el servicio de tunelacion que desees

# Opciones disponibles: ngrok

tunnel_service = "ngrok"

print("Usando", tunnel_service)


#Condicional de tunelacion del servidor



if tunnel_service == "ngrok":

    # !pip -q install pyngrok  #Aqui se instala el ngrok en el servidor

    from pyngrok import conf, ngrok



    # Obten tu token de ngrok

    print("Consigue tu authtoken de https://dashboard.ngrok.com/auth") #Consigue aqui tu token de ngrok, sera dinamico, si quieres que sea estatico, necesitaras la version premiun de ngrok

    import getpass



    # v - - - - - - - TOKEN - - - - - - - v



    authtoken = "2fC6YgNUM6dzYpsOqamaEsp066a_57f2YKf9haoRH81QK9ZF1" # <---- TOKEN NGROK (PON AQUÍ TU TOKEN [TIENE QUE ESTAR ENTRE LAS "COMILLAS"])

    ! ngrok authtoken $authtoken # logeo en ngrok



    #Establecimiento de region de ngrok



    #v - - - - - - - REGIONES DISPONIBLES - - - - - - - v

    # ap - Asia/Pacifico (Singapore)

    # au - Australia (Sydney)

    # eu - Europa (Frankfurt - Alemania)

    # in - India (Mumbai)

    # jp - Japon (Tokyo)

    # sa - America del sur (São Paulo - Brasil)

    # us - Estados unidos (Ohio)

    conf.get_default().region = 'us' # <--- Cambia esto por la region que quieras



    # Conectar a ngrok

    url = ngrok.connect(25565, 'tcp')

    print('La IP de tu servidor es ===>   ' + ((str(url).split('"')[1::2])[0]).replace('tcp://', ''))

    #Si obtienes el servicio premiun de ngrok borra las dos lineas de codigo de arriba y quitale el # a estas a continuacion:

    #subdominio = "mi-subdominio"

    #url = ngrok.connect(25565, 'tcp', subdomain=subdominio)

    #print('La IP de tu servidor es ' + url.replace('tcp://', ''))

elif tunnel_service == "playit":

    ! curl -SsL https://playit-cloud.github.io/ppa/key.gpg | sudo apt-key add -
    ! sudo curl -SsL -o /etc/apt/sources.list.d/playit-cloud.list https://playit-cloud.github.io/ppa/playit-cloud.list
    ! sudo apt update &>/dev/null && sudo apt install playit &>/dev/null && echo "Playit.gg installed" || echo "Failed to install playit"
    print('Starting server...')
    ! playit & java $memory_allocation $server_flags -jar $jar_name nogui

print('Iniciando servidor...')

def get_users():
    url = 'https://jsonplaceholder.typicode.com/users'
    try:
        response = requests.get(url)
        if response.status_code == 200:
            data = response.json()
            print("Lista de usuarios:")
            for user in data:
                print(f"Nombre: {user['name']}, Email: {user['email']}")
        else:
            print(f"Error al hacer la solicitud. Código de estado: {response.status_code}")
    except requests.RequestException as e:
        print(f"Error de conexión: {e}")

# Función para ejecutar get_users() cada 25 minutos
def repeat_get_users():
    while True:
        get_users()
        time.sleep(600)  # Espera 10 minutos

# Inicia un hilo para ejecutar repeat_get_users() en segundo plano
user_thread = threading.Thread(target=repeat_get_users)
user_thread.start()

if colabconfig["server_type"] == "forge":

    version = colabconfig["server_version"]
    
    forgefiles = f"/workspaces/codespaces-jupyter/Minecraft-server/libraries/net/minecraftforge/forge/"
    
    forgepreversion = os.listdir(forgefiles)
    
    if forgepreversion:
    
        forgeversion = forgepreversion[0]
        forgeversionchecked = forgeversion.replace(".jar", "")
        print("La versión de Forge es:", forgeversionchecked)
    
    else:
    
        print("No se encontraron archivos en el directorio Forge.")
    
    pathtoforge = glob.glob(f"/workspaces/codespaces-jupyter/Minecraft-server/libraries/net/minecraftforge/forge/{forgeversionchecked}/unix_args.txt")

    if pathtoforge: # Checa si la lista no esta vacia

        path = pathtoforge[0] # Obtiene la primera ruta de la lista

        print(path)

        # !java @user_jvm_args.txt "@{path}" "$@"

    else:

        print("No se encontro el archivo unix_args.txt.")

#Si el servidor es de tipo Vanilla o paper o mohist o catserver o purpur

else:
    #Ejecuta el archivo jar del servidor
    
    # !java $memory_allocation $server_flags -jar $jar_name nogui   

# Ciclo para realizar las solicitudes a JSONPlaceholder cada minuto

while True:
    time.sleep(60)  # Espera 1 minuto
# Out:
# el apt cache fue actualizado correctamente
# banned-ips.json      forge.jar.log  run.bat	       usercache.json
# banned-players.json  kubejs	    run.sh	       usernamecache.json
# colabconfig.json     libraries	    server-icon.png    whitelist.json
# config		     logs	    server.properties  world
# defaultconfigs	     mods	    startserver.bat
# eula.txt	     ops.json	    startserver.sh
# forge.jar	     packmenu	    user_jvm_args.txt
# OpenJDK 17 instalado correctamente
# OpenJDK 17 instalado correctamente
# Usando ngrok
# Consigue tu authtoken de https://dashboard.ngrok.com/auth
# Authtoken saved to configuration file: /home/codespace/.config/ngrok/ngrok.yml
# La IP de tu servidor es ===>   0.tcp.ngrok.io:19511
# Iniciando servidor...
# La versión de Forge es: 1.20.1-47.2.23
# /workspaces/codespaces-jupyter/Minecraft-server/libraries/net/minecraftforge/forge/1.20.1-47.2.23/unix_args.txt
# Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# [22:22:08] [main/INFO] [cp.mo.mo.Launcher/MODLAUNCHER]: ModLauncher running: args [--launchTarget, forgeserver, --fml.forgeVersion, 47.2.23, --fml.mcVersion, 1.20.1, --fml.forgeGroup, net.minecraftforge, --fml.mcpVersion, 20230612.114412]
# [22:22:08] [main/INFO] [cp.mo.mo.Launcher/MODLAUNCHER]: ModLauncher 10.0.9+10.0.9+main.dcd20f30 starting: java version 21.0.2 by Microsoft; OS Linux arch amd64 version 6.2.0-1019-azure
# [22:22:19] [main/INFO] [ne.mi.fm.lo.ImmediateWindowHandler/]: ImmediateWindowProvider not loading because launch target is forgeserver
# [22:22:19] [main/INFO] [mixin/]: SpongePowered MIXIN Subsystem Version=0.8.5 Source=union:/workspaces/codespaces-jupyter/Minecraft-server/libraries/org/spongepowered/mixin/0.8.5/mixin-0.8.5.jar%2365!/ Service=ModLauncher Env=SERVER
# [22:22:20] [main/WARN] [ne.mi.fm.lo.mo.ModFileParser/LOADING]: Mod file /workspaces/codespaces-jupyter/Minecraft-server/libraries/net/minecraftforge/fmlcore/1.20.1-47.2.23/fmlcore-1.20.1-47.2.23.jar is missing mods.toml file
# [22:22:20] [main/WARN] [ne.mi.fm.lo.mo.ModFileParser/LOADING]: Mod file /workspaces/codespaces-jupyter/Minecraft-server/libraries/net/minecraftforge/javafmllanguage/1.20.1-47.2.23/javafmllanguage-1.20.1-47.2.23.jar is missing mods.toml file
# [22:22:20] [main/WARN] [ne.mi.fm.lo.mo.ModFileParser/LOADING]: Mod file /workspaces/codespaces-jupyter/Minecraft-server/libraries/net/minecraftforge/lowcodelanguage/1.20.1-47.2.23/lowcodelanguage-1.20.1-47.2.23.jar is missing mods.toml file
# [22:22:20] [main/WARN] [ne.mi.fm.lo.mo.ModFileParser/LOADING]: Mod file /workspaces/codespaces-jupyter/Minecraft-server/libraries/net/minecraftforge/mclanguage/1.20.1-47.2.23/mclanguage-1.20.1-47.2.23.jar is missing mods.toml file
# [22:22:20] [main/WARN] [ne.mi.ja.se.JarSelector/]: Attempted to select two dependency jars from JarJar which have the same identification: Mod File:  and Mod File: . Using Mod File:
# [22:22:20] [main/WARN] [ne.mi.ja.se.JarSelector/]: Attempted to select a dependency jar for JarJar which was passed in as source: geckolib. Using Mod File: /workspaces/codespaces-jupyter/Minecraft-server/mods/geckolib-forge-1.20.1-4.4.4.jar
# [22:22:20] [main/INFO] [ne.mi.fm.lo.mo.JarInJarDependencyLocator/]: Found 31 dependencies adding them to mods collection
# t=2024-04-16T22:22:23+0000 lvl=warn msg="failed to open private leg" id=5b14766ab592 typ=proxy privaddr=localhost:25565 err="dial tcp [::1]:25565: connect: connection refused"
# t=2024-04-16T22:22:26+0000 lvl=warn msg="failed to open private leg" id=1f9c897bac98 typ=proxy privaddr=localhost:25565 err="dial tcp [::1]:25565: connect: connection refused"
# t=2024-04-16T22:22:26+0000 lvl=warn msg="failed to open private leg" id=093c1d6fb956 typ=proxy privaddr=localhost:25565 err="dial tcp [::1]:25565: connect: connection refused"
# [22:22:27] [main/INFO] [mixin/]: Compatibility level set to JAVA_17
# [22:22:27] [main/INFO] [mixin/]: Successfully loaded Mixin Connector [shetiphian.core.mixins.MixinConnector]
# [22:22:27] [main/INFO] [mixin/]: Successfully loaded Mixin Connector [com.thevortex.allthetweaks.mixin.MixinConnector]
# [22:22:27] [main/INFO] [mixin/]: Successfully loaded Mixin Connector [com.leobeliik.extremesoundmuffler.MixinConnector]
# [22:22:27] [main/INFO] [mixin/]: Successfully loaded Mixin Connector [shetiphian.endertanks.mixins.MixinConnector]
# [22:22:27] [main/INFO] [cp.mo.mo.LaunchServiceHandler/MODLAUNCHER]: Launching target 'forgeserver' with arguments []
# [22:22:27] [main/INFO] [ModernFix/]: Loaded configuration file for ModernFix 5.15.0+mc1.20.1: 77 options available, 0 override(s) found
# [22:22:27] [main/INFO] [ModernFix/]: Applying Nashorn fix
# [22:22:27] [main/INFO] [ModernFix/]: Applied Forge config corruption patch
# [22:22:28] [main/WARN] [mixin/]: Reference map 'universalgrid.refmap.json' for universalgrid.mixins.json could not be read. If this is a development environment you can ignore this message
# [22:22:28] [main/WARN] [mixin/]: Reference map 'EpheroLib-refmap.json' for epherolib.mixins.json could not be read. If this is a development environment you can ignore this message
# [22:22:28] [main/WARN] [mixin/]: Reference map 'logprot.refmap.json' for logprot.mixins.json could not be read. If this is a development environment you can ignore this message
# [22:22:28] [main/WARN] [mixin/]: Reference map 'cristellib-forge-refmap.json' for cristellib.mixins.json could not be read. If this is a development environment you can ignore this message
# [22:22:28] [main/WARN] [mixin/]: Reference map 'cookingforblockheads.refmap.json' for cookingforblockheads.mixins.json could not be read. If this is a development environment you can ignore this message
# [22:22:28] [main/WARN] [mixin/]: Reference map 'bloodmagic.refmap.json' for bloodmagic.mixins.json could not be read. If this is a development environment you can ignore this message
# [22:22:28] [main/WARN] [mixin/]: Reference map 'modonomicon.refmap.json' for modonomicon.mixins.json could not be read. If this is a development environment you can ignore this message
# [22:22:28] [main/WARN] [mixin/]: Reference map 'modonomicon.refmap.json' for modonomicon.forge.mixins.json could not be read. If this is a development environment you can ignore this message
# [22:22:28] [main/INFO] [ne.mi.co.Co.placebo/COREMODLOG]: Patching IForgeItemStack#getEnchantmentLevel
# [22:22:28] [main/INFO] [ne.mi.co.Co.placebo/COREMODLOG]: Patching IForgeItemStack#getEnchantmentLevel
# [22:22:29] [main/INFO] [ne.mi.co.Co.apotheosis/COREMODLOG]: Replaced 2 calls to Enchantment#getMaxLevel() in net/minecraft/world/inventory/AnvilMenu
# [22:22:29] [main/INFO] [ne.mi.co.Co.placebo/COREMODLOG]: Patching IForgeItemStack#getEnchantmentLevel
# [22:22:29] [main/INFO] [ne.mi.co.Co.placebo/COREMODLOG]: Patching IForgeItemStack#getEnchantmentLevel
# [22:22:30] [main/ERROR] [ne.mi.fm.lo.RuntimeDistCleaner/DISTXFORM]: Attempted to load class net/minecraft/client/multiplayer/MultiPlayerGameMode for invalid dist DEDICATED_SERVER
# [22:22:30] [main/WARN] [mixin/]: Error loading class: net/minecraft/client/multiplayer/MultiPlayerGameMode (java.lang.RuntimeException: Attempted to load class net/minecraft/client/multiplayer/MultiPlayerGameMode for invalid dist DEDICATED_SERVER)
# [22:22:30] [main/WARN] [mixin/]: @Mixin target net.minecraft.client.multiplayer.MultiPlayerGameMode was not found mixins.cofhcore.json:MultiPlayerGameModeMixin
# [22:22:30] [main/WARN] [mixin/]: Error loading class: net/dries007/tfc/common/blocks/rock/AqueductBlock (java.lang.ClassNotFoundException: net.dries007.tfc.common.blocks.rock.AqueductBlock)
# [22:22:30] [main/WARN] [mixin/]: @Mixin target net.dries007.tfc.common.blocks.rock.AqueductBlock was not found allthetweaks.mixins.json:FluiDucts
# [22:22:30] [main/INFO] [ne.mi.co.Co.apotheosis/COREMODLOG]: Patching FishingHook#catchingFish
# [22:22:30] [main/INFO] [ne.mi.co.Co.apotheosis/COREMODLOG]: Replaced 1 calls to Enchantment#getMaxLevel() in net/minecraft/world/entity/npc/VillagerTrades$EnchantBookForEmeralds
# [22:22:30] [main/INFO] [ne.mi.co.Co.apotheosis/COREMODLOG]: Replaced 1 calls to Enchantment#isTreasureOnly() in net/minecraft/world/entity/npc/VillagerTrades$EnchantBookForEmeralds
# [22:22:30] [main/INFO] [ne.mi.co.Co.apotheosis/COREMODLOG]: Replaced 1 calls to Enchantment#isTradeable() in net/minecraft/world/entity/npc/VillagerTrades$EnchantBookForEmeralds
# [22:22:30] [main/ERROR] [ne.mi.fm.lo.RuntimeDistCleaner/DISTXFORM]: Attempted to load class net/minecraft/client/gui/screens/inventory/AbstractContainerScreen for invalid dist DEDICATED_SERVER
# [22:22:30] [main/WARN] [mixin/]: Error loading class: net/minecraft/client/gui/screens/inventory/AbstractContainerScreen (java.lang.RuntimeException: Attempted to load class net/minecraft/client/gui/screens/inventory/AbstractContainerScreen for invalid dist DEDICATED_SERVER)
# [22:22:30] [main/WARN] [mixin/]: @Mixin target net.minecraft.client.gui.screens.inventory.AbstractContainerScreen was not found findme-common.mixins.json:MixinSlotRenderer
# [22:22:30] [main/ERROR] [ne.mi.fm.lo.RuntimeDistCleaner/DISTXFORM]: Attempted to load class net/minecraft/client/particle/ParticleEngine for invalid dist DEDICATED_SERVER
# [22:22:30] [main/WARN] [mixin/]: Error loading class: net/minecraft/client/particle/ParticleEngine (java.lang.RuntimeException: Attempted to load class net/minecraft/client/particle/ParticleEngine for invalid dist DEDICATED_SERVER)
# [22:22:30] [main/WARN] [mixin/]: @Mixin target net.minecraft.client.particle.ParticleEngine was not found findme-common.mixins.json:ParticleEngineAccessor
# [22:22:30] [main/WARN] [mixin/]: Error loading class: de/maxhenkel/voicechat/plugins/impl/audiochannel/EntityAudioChannelImpl (java.lang.ClassNotFoundException: de.maxhenkel.voicechat.plugins.impl.audiochannel.EntityAudioChannelImpl)
# [22:22:30] [main/WARN] [mixin/]: @Mixin target de.maxhenkel.voicechat.plugins.impl.audiochannel.EntityAudioChannelImpl was not found railways-common.mixins.json:compat.voicechat.EntityAudioChannelImplMixin
# [22:22:30] [main/WARN] [mixin/]: Error loading class: de/maxhenkel/voicechat/voice/server/Server (java.lang.ClassNotFoundException: de.maxhenkel.voicechat.voice.server.Server)
# [22:22:30] [main/WARN] [mixin/]: @Mixin target de.maxhenkel.voicechat.voice.server.Server was not found railways-common.mixins.json:compat.voicechat.ServerMixin
# [22:22:30] [main/WARN] [mixin/]: Error loading class: de/maxhenkel/voicechat/voice/server/ServerWorldUtils (java.lang.ClassNotFoundException: de.maxhenkel.voicechat.voice.server.ServerWorldUtils)
# [22:22:30] [main/WARN] [mixin/]: @Mixin target de.maxhenkel.voicechat.voice.server.ServerWorldUtils was not found railways-common.mixins.json:compat.voicechat.ServerWorldUtilsMixin
# [22:22:31] [main/WARN] [mixin/]: Error loading class: net/minecraft/client/renderer/entity/PhantomRenderer (java.lang.ClassNotFoundException: net.minecraft.client.renderer.entity.PhantomRenderer)
# [22:22:31] [main/WARN] [mixin/]: @Mixin target net.minecraft.client.renderer.entity.PhantomRenderer was not found mixins.deeperdarker.json:PhantomRendererMixin
# [22:22:31] [main/INFO] [ne.mi.co.Co.apotheosis/COREMODLOG]: Replaced 2 calls to Enchantment#getMaxLevel() in net/minecraft/world/item/CreativeModeTabs
# [22:22:31] [main/INFO] [ne.mi.co.Co.apotheosis/COREMODLOG]: Replaced 1 calls to Enchantment#getMaxLevel() in net/minecraft/world/level/storage/loot/functions/EnchantRandomlyFunction
# [22:22:31] [main/INFO] [ne.mi.co.Co.apotheosis/COREMODLOG]: Replaced 1 calls to Enchantment#isDiscoverable() in net/minecraft/world/level/storage/loot/functions/EnchantRandomlyFunction
# [22:22:31] [main/WARN] [mixin/]: Error loading class: vazkii/quark/addons/oddities/inventory/BackpackMenu (java.lang.ClassNotFoundException: vazkii.quark.addons.oddities.inventory.BackpackMenu)
# [22:22:31] [main/WARN] [mixin/]: Error loading class: net/minecraft/client/gui/screens/inventory/CraftingScreen (java.lang.ClassNotFoundException: net.minecraft.client.gui.screens.inventory.CraftingScreen)
# [22:22:31] [main/WARN] [mixin/]: @Mixin target net.minecraft.client.gui.screens.inventory.CraftingScreen was not found fastbench.mixins.json:MixinCraftingScreen
# [22:22:31] [main/INFO] [MixinExtras|Service/]: Initializing MixinExtras via com.llamalad7.mixinextras.service.MixinExtrasServiceImpl(version=0.3.2).
# [22:22:32] [main/INFO] [mixin/]: Mixing server.MixinDedicatedServer from mixins/common/nochatreports.mixins.json into net.minecraft.server.dedicated.DedicatedServer
# [22:22:32] [main/WARN] [mixin/]: Static binding violation: PRIVATE @Overwrite method m_216202_ in modernfix-forge.mixins.json:perf.tag_id_caching.TagOrElementLocationMixin cannot reduce visibiliy of PUBLIC target method, visibility will be upgraded.
# [22:22:32] [main/INFO] [minecraft/Bootstrap]: ModernFix reached bootstrap stage (27.58 s after launch)
# [22:22:32] [main/WARN] [mixin/]: @Final field delegatesByName:Ljava/util/Map; in modernfix-forge.mixins.json:perf.forge_registry_alloc.ForgeRegistryMixin should be final
# [22:22:32] [main/WARN] [mixin/]: @Final field delegatesByValue:Ljava/util/Map; in modernfix-forge.mixins.json:perf.forge_registry_alloc.ForgeRegistryMixin should be final
# [22:22:34] [main/INFO] [ne.mi.co.Co.apotheosis/COREMODLOG]: Replaced 2 calls to Enchantment#getMaxLevel() in net/minecraft/world/item/CreativeModeTabs
# [22:22:34] [main/INFO] [ne.mi.co.Co.apotheosis/COREMODLOG]: Replaced 1 calls to Enchantment#getMaxLevel() in org/violetmoon/quark/content/experimental/module/GameNerfsModule
# [22:22:35] [main/INFO] [minecraft/Bootstrap]: Vanilla bootstrap took 2552 milliseconds
# [22:22:35] [main/INFO] [mixin/]: Mixing common.MixinFriendlyByteBuf from mixins/common/nochatreports.mixins.json into net.minecraft.network.FriendlyByteBuf
# [22:22:35] [main/INFO] [mixin/]: Renaming synthetic method lambda$onWriteJsonWithCodec$1(Ljava/lang/Object;Ljava/lang/String;)Lio/netty/handler/codec/EncoderException; to mdcfe910$lambda$onWriteJsonWithCodec$1$0 in mixins/common/nochatreports.mixins.json:common.MixinFriendlyByteBuf
# [22:22:35] [main/INFO] [mixin/]: Renaming synthetic method lambda$onReadJsonWithCodec$0(Ljava/lang/String;)Lio/netty/handler/codec/DecoderException; to mdcfe910$lambda$onReadJsonWithCodec$0$1 in mixins/common/nochatreports.mixins.json:common.MixinFriendlyByteBuf
# [22:22:35] [main/INFO] [ne.mi.co.Co.apotheosis/COREMODLOG]: Replaced 5 calls to Enchantment#getMaxLevel() in org/violetmoon/quark/content/tools/module/AncientTomesModule
# [22:22:35] [main/INFO] [ne.mi.co.Co.placebo/COREMODLOG]: Patching IForgeItemStack#getEnchantmentLevel
# [22:22:35] [main/INFO] [ne.mi.co.Co.placebo/COREMODLOG]: Patching IForgeItemStack#getEnchantmentLevel
# [22:22:36] [main/INFO] [ne.mi.co.Co.apotheosis/COREMODLOG]: Replaced 2 calls to Enchantment#getMaxLevel() in net/minecraft/world/inventory/AnvilMenu
# [22:22:37] [main/INFO] [ne.mi.co.Co.apotheosis/COREMODLOG]: Patching FishingHook#catchingFish
# [22:22:37] [main/INFO] [mixin/]: Mixing server.MixinServerGamePacketListenerImpl from mixins/common/nochatreports.mixins.json into net.minecraft.server.network.ServerGamePacketListenerImpl
# t=2024-04-16T22:22:37+0000 lvl=warn msg="failed to open private leg" id=3998013ef0ae typ=proxy privaddr=localhost:25565 err="dial tcp [::1]:25565: connect: connection refused"
# [22:22:38] [main/INFO] [ne.mi.co.Co.apotheosis/COREMODLOG]: Replaced 1 calls to Enchantment#getMaxLevel() in net/minecraft/world/level/storage/loot/functions/EnchantRandomlyFunction
# [22:22:38] [main/INFO] [ne.mi.co.Co.apotheosis/COREMODLOG]: Replaced 1 calls to Enchantment#isDiscoverable() in net/minecraft/world/level/storage/loot/functions/EnchantRandomlyFunction
# t=2024-04-16T22:22:38+0000 lvl=warn msg="failed to open private leg" id=6c69d49d33ee typ=proxy privaddr=localhost:25565 err="dial tcp [::1]:25565: connect: connection refused"
# [22:22:38] [main/WARN] [mixin/]: Static binding violation: PRIVATE @Overwrite method m_47505_ in modernfix-common.mixins.json:perf.remove_biome_temperature_cache.BiomeMixin cannot reduce visibiliy of PUBLIC target method, visibility will be upgraded.
# t=2024-04-16T22:22:38+0000 lvl=warn msg="failed to open private leg" id=7aaadb654b06 typ=proxy privaddr=localhost:25565 err="dial tcp [::1]:25565: connect: connection refused"
# t=2024-04-16T22:22:39+0000 lvl=warn msg="failed to open private leg" id=240dc0e0a5ad typ=proxy privaddr=localhost:25565 err="dial tcp [::1]:25565: connect: connection refused"
# [22:22:39] [main/INFO] [co.al.me.MERequester/]: Registering content
# [22:22:50] [modloading-worker-0/INFO] [mixin/]: Mixing server.MixinPlayerList from mixins/common/nochatreports.mixins.json into net.minecraft.server.players.PlayerList
# [22:22:50] [modloading-worker-0/INFO] [cabletiers/]: Loading config: /workspaces/codespaces-jupyter/Minecraft-server/config/cabletiers-common.toml
# [22:22:50] [modloading-worker-0/INFO] [cabletiers/]: Built config: /workspaces/codespaces-jupyter/Minecraft-server/config/cabletiers-common.toml
# [22:22:50] [modloading-worker-0/INFO] [cabletiers/]: Loaded config: /workspaces/codespaces-jupyter/Minecraft-server/config/cabletiers-common.toml
# [22:22:50] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Configuration file /workspaces/codespaces-jupyter/Minecraft-server/config/cabletiers-common.toml is not correct. Correcting
# [22:22:50] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key Elite Tier Options was corrected from null to its default, SimpleCommentedConfig:{}.
# [22:22:50] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key Elite Tier Options.eliteExporterSpeed was corrected from null to its default, 2.0.
# [22:22:50] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key Elite Tier Options.eliteImporterSpeed was corrected from null to its default, 2.0.
# [22:22:50] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key Elite Tier Options.eliteConstructorSpeed was corrected from null to its default, 2.0.
# [22:22:50] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key Elite Tier Options.eliteDestructorSpeed was corrected from null to its default, 2.0.
# [22:22:50] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key Elite Tier Options.eliteDiskManipulatorSpeed was corrected from null to its default, 2.0.
# [22:22:50] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key Elite Tier Options.eliteInterfaceSpeed was corrected from null to its default, 2.0.
# [22:22:50] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key Elite Tier Options.eliteRequesterMaxCraftAmount was corrected from null to its default, 2000.
# [22:22:50] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key Elite Tier Options.eliteEnergyCost was corrected from null to its default, 2.
# [22:22:50] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key Ultra Tier Options was corrected from null to its default, SimpleCommentedConfig:{}.
# [22:22:50] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key Ultra Tier Options.ultraExporterSpeed was corrected from null to its default, 5.0.
# [22:22:50] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key Ultra Tier Options.ultraImporterSpeed was corrected from null to its default, 5.0.
# [22:22:50] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key Ultra Tier Options.ultraConstructorSpeed was corrected from null to its default, 5.0.
# [22:22:50] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key Ultra Tier Options.ultraDestructorSpeed was corrected from null to its default, 5.0.
# [22:22:50] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key Ultra Tier Options.ultraDiskManipulatorSpeed was corrected from null to its default, 5.0.
# [22:22:50] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key Ultra Tier Options.ultraInterfaceSpeed was corrected from null to its default, 5.0.
# [22:22:50] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key Ultra Tier Options.ultraRequesterMaxCraftAmount was corrected from null to its default, 4000.
# [22:22:50] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key Ultra Tier Options.ultraEnergyCost was corrected from null to its default, 3.
# [22:22:50] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key Mega Tier Options was corrected from null to its default, SimpleCommentedConfig:{}.
# [22:22:50] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key Mega Tier Options.megaExporterSpeed was corrected from null to its default, 6.5.
# [22:22:50] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key Mega Tier Options.megaImporterSpeed was corrected from null to its default, 6.5.
# [22:22:50] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key Mega Tier Options.megaConstructorSpeed was corrected from null to its default, 6.5.
# [22:22:50] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key Mega Tier Options.megaDestructorSpeed was corrected from null to its default, 6.5.
# [22:22:50] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key Mega Tier Options.megaDiskManipulatorSpeed was corrected from null to its default, 6.5.
# [22:22:50] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key Mega Tier Options.megaInterfaceSpeed was corrected from null to its default, 6.5.
# [22:22:50] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key Mega Tier Options.megaRequesterMaxCraftAmount was corrected from null to its default, 6000.
# [22:22:50] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key Mega Tier Options.megaEnergyCost was corrected from null to its default, 4.
# [22:22:50] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Configuration file /workspaces/codespaces-jupyter/Minecraft-server/config/shrink-common.toml is not correct. Correcting
# [22:22:50] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key enablePowerRequirements was corrected from null to its default, true.
# [22:22:50] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key setPowerUsage was corrected from null to its default, 5000.
# [22:22:50] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key setShrinkingDeviceCapacity was corrected from null to its default, 100000.
# [22:22:50] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key enableMobBottles was corrected from null to its default, true.
# [22:22:50] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key maxSize was corrected from null to its default, 10.0.
# [22:22:50] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key minSize was corrected from null to its default, 0.21.
# [22:22:50] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key enableShrinkInSpectator was corrected from null to its default, false.
# [22:22:50] [modloading-worker-0/INFO] [universalgrid/]: Loading config: /workspaces/codespaces-jupyter/Minecraft-server/config/universalgrid-common.toml
# [22:22:50] [modloading-worker-0/INFO] [universalgrid/]: Built config: /workspaces/codespaces-jupyter/Minecraft-server/config/universalgrid-common.toml
# [22:22:50] [modloading-worker-0/INFO] [universalgrid/]: Loaded config: /workspaces/codespaces-jupyter/Minecraft-server/config/universalgrid-common.toml
# [22:22:50] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Configuration file /workspaces/codespaces-jupyter/Minecraft-server/config/universalgrid-common.toml is not correct. Correcting
# [22:22:50] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key useEnergy was corrected from null to its default, true.
# [22:22:50] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key capacity was corrected from null to its default, 6400.
# [22:22:50] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key openUsage was corrected from null to its default, 60.
# [22:22:50] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key craftUsage was corrected from null to its default, 2.
# [22:22:50] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key clearUsage was corrected from null to its default, 20.
# [22:22:50] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id architectury:sync_ids
# [22:22:50] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id powah:packet
# [22:22:50] [modloading-worker-0/INFO] [create_new_age/]: Hello 1.20.1 Create!
# [22:22:50] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Configuration file /workspaces/codespaces-jupyter/Minecraft-server/config/jeresources.toml is not correct. Correcting
# [22:22:50] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key itemsPerColumn was corrected from null to its default, 4.
# [22:22:50] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key itemsPerRow was corrected from null to its default, 4.
# [22:22:50] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key diyData was corrected from null to its default, true.
# [22:22:50] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key showDevData was corrected from null to its default, false.
# [22:22:50] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key enchantsBlacklist was corrected from null to its default, [flimflam, soulBound].
# [22:22:50] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key hiddenTabs was corrected from null to its default, [].
# [22:22:50] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key dimensionsBlacklist was corrected from null to its default, [-11].
# [22:22:50] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key disableLootManagerReloading was corrected from null to its default, false.
# [22:22:50] [modloading-worker-0/INFO] [ne.pe.no.NoVillagerDeathMessages/]: Registering mod: novillagerdm
# [22:22:50] [modloading-worker-0/INFO] [PluginManager/]: Scanning classes for industrialforegoing
# [22:22:50] [modloading-worker-0/INFO] [PluginManager/]: Found FeaturePluginInstance for class PatchouliPlugin for plugin patchouli
# [22:22:50] [modloading-worker-0/INFO] [PluginManager/]: Found FeaturePluginInstance for class CuriosPlugin for plugin curios
# [22:22:50] [modloading-worker-0/INFO] [PluginManager/]: Constructed class PatchouliPlugin for plugin patchouli for mod industrialforegoing
# [22:22:50] [modloading-worker-0/INFO] [PluginManager/]: Constructed class CuriosPlugin for plugin curios for mod industrialforegoing
# [22:22:50] [modloading-worker-0/INFO] [PluginManager/]: Executing phase CONSTRUCTION for plugin class PatchouliPlugin
# [22:22:50] [modloading-worker-0/INFO] [PluginManager/]: Executing phase CONSTRUCTION for plugin class CuriosPlugin
# [22:22:50] [modloading-worker-0/INFO] [PluginManager/]: Executing phase PRE_INIT for plugin class PatchouliPlugin
# [22:22:50] [modloading-worker-0/INFO] [PluginManager/]: Executing phase PRE_INIT for plugin class CuriosPlugin
# [22:22:51] [modloading-worker-0/WARN] [mixin/]: Static binding violation: PRIVATE @Overwrite method m_215924_ in modernfix-forge.mixins.json:perf.tag_id_caching.TagEntryMixin cannot reduce visibiliy of PUBLIC target method, visibility will be upgraded.
# [22:22:51] [modloading-worker-0/WARN] [ir.IronFurnaces/]: You have disabled Iron Furnaces's Update Checker, to re-enable: change the value of Update Checker in .minecraft->config->ironfurnaces-client.toml to 'true'.
# [22:22:51] [modloading-worker-0/INFO] [PluginManager/]: Executing phase INIT for plugin class PatchouliPlugin
# [22:22:51] [modloading-worker-0/INFO] [PluginManager/]: Executing phase INIT for plugin class CuriosPlugin
# [22:22:51] [modloading-worker-0/INFO] [PluginManager/]: Executing phase POST_INIT for plugin class PatchouliPlugin
# [22:22:51] [modloading-worker-0/INFO] [PluginManager/]: Executing phase POST_INIT for plugin class CuriosPlugin
# [22:22:51] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Configuration file /workspaces/codespaces-jupyter/Minecraft-server/config/flib.toml is not correct. Correcting
# [22:22:51] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key flib was corrected from null to its default, SimpleCommentedConfig:{}.
# [22:22:51] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key flib.command was corrected from null to its default, SimpleCommentedConfig:{}.
# [22:22:51] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key flib.command.enabled was corrected from null to its default, true.
# [22:22:51] [modloading-worker-0/INFO] [de.me.ex.ExtraDisks/]: 14 blocks registered.
# [22:22:51] [modloading-worker-0/INFO] [de.me.ex.ExtraDisks/]: 29 items registered.
# [22:22:51] [modloading-worker-0/INFO] [de.me.ex.ExtraDisks/]: 13 tiles registered.
# [22:22:51] [modloading-worker-0/INFO] [de.me.ex.ExtraDisks/]: 13 containers registered.
# [22:22:52] [modloading-worker-0/INFO] [ne.mi.co.ForgeMod/FORGEMOD]: Forge mod loading, version 47.2.23, for MC 1.20.1 with MCP 20230612.114412
# [22:22:52] [modloading-worker-0/INFO] [ne.mi.co.MinecraftForge/FORGE]: MinecraftForge v47.2.23 Initialized
# [22:22:52] [modloading-worker-0/INFO] [libx/]: Config 'mythicbotany:config' does not exist. Creating default.
# [Mouse Tweaks] Disabled because not running on the client.
# [22:22:52] [modloading-worker-0/INFO] [NoChatReports/]: KONNICHIWA ZA WARUDO!
# [22:22:52] [modloading-worker-0/INFO] [NoChatReports/]: Default JVM text encoding is: UTF-8
# [22:22:52] [modloading-worker-0/INFO] [NoChatReports/]: Reading config file NoChatReports/NCR-Common.json...
# [22:22:52] [modloading-worker-0/INFO] [NoChatReports/]: Writing config file NoChatReports/NCR-Common.json...
# [22:22:52] [modloading-worker-0/INFO] [pneumaticcraft/]: Thirdparty integration activated for [cofh_core,immersiveengineering,computercraft,jei,botania,mekanism,curios,patchouli,create]
# [22:22:53] [modloading-worker-0/INFO] [co.ep.ep.co.CommonConfig/]: Creating default config file: croptopia_v3.conf
# [22:22:53] [modloading-worker-0/INFO] [th.ko.te.KotlinForForge/]: Kotlin For Forge Enabled!
# [22:22:53] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Configuration file /workspaces/codespaces-jupyter/Minecraft-server/config/appleskin-client.toml is not correct. Correcting
# [22:22:53] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key client was corrected from null to its default, SimpleCommentedConfig:{}.
# [22:22:53] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key client.showFoodValuesInTooltip was corrected from null to its default, true.
# [22:22:53] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key client.showFoodValuesInTooltipAlways was corrected from null to its default, true.
# [22:22:53] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key client.showSaturationHudOverlay was corrected from null to its default, true.
# [22:22:53] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key client.showFoodValuesHudOverlay was corrected from null to its default, true.
# [22:22:53] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key client.showFoodValuesHudOverlayWhenOffhand was corrected from null to its default, true.
# [22:22:53] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key client.showFoodExhaustionHudUnderlay was corrected from null to its default, true.
# [22:22:53] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key client.showFoodStatsInDebugOverlay was corrected from null to its default, true.
# [22:22:53] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key client.showFoodHealthHudOverlay was corrected from null to its default, true.
# [22:22:53] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key client.showVanillaAnimationsOverlay was corrected from null to its default, true.
# [22:22:53] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key client.maxHudOverlayFlashAlpha was corrected from null to its default, 0.65.
# [22:22:53] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Configuration file /workspaces/codespaces-jupyter/Minecraft-server/config/lootr-common.toml is not correct. Correcting
# [22:22:53] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key randomise_seed was corrected from null to its default, true.
# [22:22:53] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key max_age was corrected from null to its default, 18000.
# [22:22:53] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key disable was corrected from null to its default, false.
# [22:22:53] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key convert_mineshafts was corrected from null to its default, true.
# [22:22:53] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key convert_elytras was corrected from null to its default, true.
# [22:22:53] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key convert_wooden_chests was corrected from null to its default, true.
# [22:22:53] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key convert_trapped_chests was corrected from null to its default, true.
# [22:22:53] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key report_unresolved_tables was corrected from null to its default, false.
# [22:22:53] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key additional_chests was corrected from null to its default, [].
# [22:22:53] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key additional_trapped_chests was corrected from null to its default, [].
# [22:22:53] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key dimension_whitelist was corrected from null to its default, [].
# [22:22:53] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key dimension_blacklist was corrected from null to its default, [].
# [22:22:53] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key modid_dimension_blacklist was corrected from null to its default, [].
# [22:22:53] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key modid_dimension_whitelist was corrected from null to its default, [].
# [22:22:53] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key loot_table_blacklist was corrected from null to its default, [].
# [22:22:53] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key loot_modid_blacklist was corrected from null to its default, [].
# [22:22:53] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key disable_break was corrected from null to its default, false.
# [22:22:53] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key enable_break was corrected from null to its default, false.
# [22:22:53] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Configuration file /workspaces/codespaces-jupyter/Minecraft-server/config/zeta-common.toml is not correct. Correcting
# [22:22:53] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key general was corrected from null to its default, SimpleCommentedConfig:{}.
# [22:22:53] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key general.Use Anti Overlap was corrected from null to its default, true.
# [22:22:53] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key general.Use Piston Logic Replacement was corrected from null to its default, true.
# [22:22:53] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key general.Piston Push Limit was corrected from null to its default, 12.
# [22:22:53] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key general.Hide Disabled Content was corrected from null to its default, true.
# [22:22:53] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key general.Enable Jei Item Info was corrected from null to its default, true.
# [22:22:53] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key general.Suppressed Info was corrected from null to its default, [].
# [22:22:53] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key general.Enable Advancement Modification was corrected from null to its default, true.
# [22:22:53] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key general.Enable Modded Advancements was corrected from null to its default, true.
# [22:22:53] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key general.Enable Worldgen Watchdog was corrected from null to its default, false.
# [22:22:53] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key general.Use Fast Worldgen was corrected from null to its default, false.
# [22:22:53] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key check_world_border was corrected from null to its default, false.
# [22:22:53] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key enable_fake_player_break was corrected from null to its default, false.
# [22:22:53] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key power_comparators was corrected from null to its default, true.
# [22:22:53] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key trapped_custom was corrected from null to its default, false.
# [22:22:53] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key blast_resistant was corrected from null to its default, false.
# [22:22:53] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key blast_immune was corrected from null to its default, false.
# [22:22:53] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key disable_notifications was corrected from null to its default, false.
# [22:22:53] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key notification_delay was corrected from null to its default, 600.
# [22:22:53] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key disable_message_styles was corrected from null to its default, false.
# [22:22:53] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key decay_value was corrected from null to its default, 6000.
# [22:22:53] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key decay_loot_tables was corrected from null to its default, [].
# [22:22:53] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key decay_modids was corrected from null to its default, [].
# [22:22:53] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key decay_dimensions was corrected from null to its default, [].
# [22:22:53] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key decay_structures was corrected from null to its default, [].
# [22:22:53] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key decay_all was corrected from null to its default, false.
# [22:22:53] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key refresh_value was corrected from null to its default, 24000.
# [22:22:53] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key refresh_loot_tables was corrected from null to its default, [].
# [22:22:53] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key refresh_modids was corrected from null to its default, [].
# [22:22:53] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key refresh_dimensions was corrected from null to its default, [].
# [22:22:53] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key refresh_structures was corrected from null to its default, [].
# [22:22:53] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key refresh_all was corrected from null to its default, false.
# [22:22:53] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Configuration file /workspaces/codespaces-jupyter/Minecraft-server/config/lootr-client.toml is not correct. Correcting
# [22:22:53] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key vanilla_textures was corrected from null to its default, false.
# [22:22:53] [modloading-worker-0/WARN] [mixin/]: Method overwrite conflict for getPalettes in ars_nouveau.mixins.json:structure.StructureTemplateAccessor, previously written by com.almostreliable.morejs.mixin.structure.StructureTemplateMixin. Skipping method.
# [22:22:53] [modloading-worker-0/WARN] [mixin/]: Method overwrite conflict for getPalettes in immersiveengineering.mixins.json:accessors.TemplateAccess, previously written by com.almostreliable.morejs.mixin.structure.StructureTemplateMixin. Skipping method.
# [22:22:53] [modloading-worker-0/INFO] [Advanced Peripherals/]: AdvancedPeripherals says hello!
# [22:22:53] [modloading-worker-0/WARN] [Advanced Peripherals/]: Successfully loaded integration for powah
# [22:22:53] [modloading-worker-0/WARN] [Advanced Peripherals/]: Successfully loaded integration for create
# [22:22:53] [modloading-worker-0/WARN] [Advanced Peripherals/]: Successfully loaded integration for mekanism
# [22:22:53] [modloading-worker-0/INFO] [libx/]: Config 'utilitix:common' does not exist. Creating default.
# [22:22:54] [modloading-worker-0/INFO] [Bookshelf/]: Fixing MC-151457. Crafting remainder for minecraft:pufferfish_bucket is now minecraft:bucket.
# [22:22:54] [modloading-worker-0/INFO] [Bookshelf/]: Fixing MC-151457. Crafting remainder for minecraft:salmon_bucket is now minecraft:bucket.
# [22:22:54] [modloading-worker-0/INFO] [Bookshelf/]: Fixing MC-151457. Crafting remainder for minecraft:cod_bucket is now minecraft:bucket.
# [22:22:54] [modloading-worker-0/INFO] [Bookshelf/]: Fixing MC-151457. Crafting remainder for minecraft:tropical_fish_bucket is now minecraft:bucket.
# [22:22:54] [modloading-worker-0/INFO] [Bookshelf/]: Fixing MC-151457. Crafting remainder for minecraft:axolotl_bucket is now minecraft:bucket.
# [22:22:54] [modloading-worker-0/INFO] [Bookshelf/]: Fixing MC-151457. Crafting remainder for minecraft:powder_snow_bucket is now minecraft:bucket.
# [22:22:54] [modloading-worker-0/INFO] [Bookshelf/]: Fixing MC-151457. Crafting remainder for minecraft:tadpole_bucket is now minecraft:bucket.
# [22:22:54] [modloading-worker-0/INFO] [pl.dr.cr.DragonLib/]: Create: Dragon Lib 1.4.1 has initialized, ready to support your Create add-ons!
# [22:22:54] [modloading-worker-0/INFO] [cy.jd.ut.Utilitarian/]: setting up server config
# [22:22:55] [modloading-worker-0/INFO] [de.ke.ko.Konkrete/]: [KONKRETE] Successfully initialized!
# [22:22:55] [modloading-worker-0/INFO] [de.ke.ko.Konkrete/]: [KONKRETE] Server-side libs ready to use!
# [22:22:55] [modloading-worker-0/INFO] [co.re.re.ap.API/]: Found 3 RS API injection points
# [22:22:55] [modloading-worker-0/INFO] [co.re.re.ap.API/]: Injected RS API in com.ultramega.universalgrid.UniversalGrid RSAPI
# [22:22:55] [modloading-worker-0/INFO] [co.re.re.ap.API/]: Injected RS API in net.gigabit101.rebornstorage.RebornStorage RSAPI
# [22:22:55] [modloading-worker-0/INFO] [co.re.re.ap.API/]: Injected RS API in com.refinedmods.refinedstorageaddons.RSAddons RSAPI
# [22:22:56] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Configuration file /workspaces/codespaces-jupyter/Minecraft-server/config/rebornstorage-common.toml is not correct. Correcting
# [22:22:56] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key general was corrected from null to its default, SimpleCommentedConfig:{}.
# [22:22:56] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key general.multiblock_crafter_frame_cost was corrected from null to its default, 0.
# [22:22:56] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key general.multiblock_crafter_heat_cost was corrected from null to its default, 0.
# [22:22:56] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key general.multiblock_crafter_cpu_cost was corrected from null to its default, 5.
# [22:22:56] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key general.multiblock_crafter_storage_cost was corrected from null to its default, 10.
# [22:22:56] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key multiblock was corrected from null to its default, SimpleCommentedConfig:{}.
# [22:22:56] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key multiblock.multiblock_crafter_max_x was corrected from null to its default, 16.
# [22:22:56] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key multiblock.multiblock_crafter_max_y was corrected from null to its default, 16.
# [22:22:56] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key multiblock.multiblock_crafter_max_z was corrected from null to its default, 16.
# [22:22:56] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key multiblock.multiblock_crafter_min_x was corrected from null to its default, 3.
# [22:22:56] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key multiblock.multiblock_crafter_min_y was corrected from null to its default, 3.
# [22:22:56] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key multiblock.multiblock_crafter_min_z was corrected from null to its default, 3.
# [22:22:56] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key multiblock.advanced_wireless_transmitter_range was corrected from null to its default, 1000.
# [22:22:56] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key multiblock.advanced_wireless_transmitter_cost was corrected from null to its default, 100.
# [22:22:56] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key multiblock.advanced_wireless_transmitter_range_booster_range was corrected from null to its default, 500.
# [22:22:56] [modloading-worker-0/INFO] [railways/]: Registered bogey styles from railways
# [22:22:56] [modloading-worker-0/INFO] [PluginManager/]: Scanning classes for industrialforegoingsouls
# [22:22:56] [modloading-worker-0/INFO] [railways/]: Registering data fixers
# [22:22:56] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id ftbultimine:key_pressed
# [22:22:56] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id ftbultimine:mode_changed
# [22:22:56] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id ftbultimine:sync_config_to_server
# [22:22:56] [modloading-worker-0/INFO] [de.ft.mo.ft.FTBUltimine/]: FTB Ranks detected, listening for ranks events
# [22:22:56] [modloading-worker-0/INFO] [Inventory Profiles Next/]: [Inventory Profiles Next] Inventory Profiles Next - init in Kotlin
# [22:22:56] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id ftblibrary:edit_nbt_response
# ...
# [22:24:30] [Server thread/WARN] [co.cu.Cupboard/]: Config clickadv.json not found, recreating default
# [22:24:30] [Server thread/INFO] [co.cu.Cupboard/]: Loaded config for: clickadv.json
# [22:24:30] [Server thread/INFO] [sh.en.EnderChests/]: Loading EnderChest Data
# [22:24:30] [Server thread/INFO] [sh.en.EnderChests/]: Finished Loading EnderChest Data
# [22:24:31] [Server thread/INFO] [MEGA Cells/]: (Re-)initialised bulk cell compression.
# [22:24:31] [Server thread/INFO] [patchouli/]: Sending reload packet to clients
# [22:24:32] [Server thread/INFO] [immersiveengineering/]: Couldn't fully analyze 1 supremium_leggings, missing knowledge for {1 imperium_leggings=1.0}
# [22:24:32] [Server thread/INFO] [immersiveengineering/]: Couldn't fully analyze 1 tertium_leggings, missing knowledge for {1 prudentium_leggings=1.0}
# [22:24:32] [Server thread/INFO] [immersiveengineering/]: Couldn't fully analyze 1 free_runners_armored, missing knowledge for {1 free_runners=1.0}
# [22:24:32] [Server thread/INFO] [immersiveengineering/]: Couldn't fully analyze 1 prudentium_shovel, missing knowledge for {1 inferium_shovel=1.0}
# [22:24:32] [Server thread/INFO] [immersiveengineering/]: Couldn't fully analyze 1 tertium_sickle, missing knowledge for {1 prudentium_sickle=1.0}
# [22:24:32] [Server thread/INFO] [immersiveengineering/]: Couldn't fully analyze 1 tertium_hoe, missing knowledge for {1 prudentium_hoe=1.0}
# [22:24:32] [Server thread/INFO] [immersiveengineering/]: Couldn't fully analyze 1 supremium_helmet, missing knowledge for {1 imperium_helmet=1.0}
# [22:24:32] [Server thread/INFO] [immersiveengineering/]: Couldn't fully analyze 1 inferium_hoe, missing knowledge for {1 diamond_hoe=1.0}
# [22:24:32] [Server thread/INFO] [immersiveengineering/]: Couldn't fully analyze 1 inferium_helmet, missing knowledge for {1 diamond_helmet=1.0}
# [22:24:32] [Server thread/INFO] [immersiveengineering/]: Couldn't fully analyze 1 imperium_scythe, missing knowledge for {1 tertium_scythe=1.0}
# [22:24:32] [Server thread/INFO] [immersiveengineering/]: Couldn't fully analyze 1 inferium_sword, missing knowledge for {1 diamond_sword=1.0}
# [22:24:32] [Server thread/INFO] [immersiveengineering/]: Couldn't fully analyze 1 netherite_space_suit, missing knowledge for {1 netherite_chestplate=1.0}
# [22:24:32] [Server thread/INFO] [immersiveengineering/]: Couldn't fully analyze 1 imperium_pickaxe, missing knowledge for {1 tertium_pickaxe=1.0}
# [22:24:32] [Server thread/INFO] [immersiveengineering/]: Couldn't fully analyze 1 imperium_sickle, missing knowledge for {1 tertium_sickle=1.0}
# [22:24:32] [Server thread/INFO] [immersiveengineering/]: Couldn't fully analyze 1 imperium_helmet, missing knowledge for {1 tertium_helmet=1.0}
# [22:24:32] [Server thread/INFO] [immersiveengineering/]: Couldn't fully analyze 1 supremium_shovel, missing knowledge for {1 imperium_shovel=1.0}
# [22:24:32] [Server thread/INFO] [immersiveengineering/]: Couldn't fully analyze 1 prudentium_pickaxe, missing knowledge for {1 inferium_pickaxe=1.0}
# [22:24:32] [Server thread/INFO] [immersiveengineering/]: Couldn't fully analyze 1 prudentium_helmet, missing knowledge for {1 inferium_helmet=1.0}
# [22:24:32] [Server thread/INFO] [immersiveengineering/]: Couldn't fully analyze 1 tertium_helmet, missing knowledge for {1 prudentium_helmet=1.0}
# [22:24:32] [Server thread/INFO] [immersiveengineering/]: Couldn't fully analyze 1 inferium_sickle, missing knowledge for {1 diamond_sickle=1.0}
# [22:24:32] [Server thread/INFO] [immersiveengineering/]: Couldn't fully analyze 1 prudentium_sword, missing knowledge for {1 inferium_sword=1.0}
# [22:24:32] [Server thread/INFO] [immersiveengineering/]: Couldn't fully analyze 1 imperium_boots, missing knowledge for {1 tertium_boots=1.0}
# [22:24:32] [Server thread/INFO] [immersiveengineering/]: Couldn't fully analyze 1 jet_suit_boots, missing knowledge for {1 netherite_space_boots=1.0}
# [22:24:32] [Server thread/INFO] [immersiveengineering/]: Couldn't fully analyze 1 inferium_axe, missing knowledge for {1 diamond_axe=1.0}
# [22:24:32] [Server thread/INFO] [immersiveengineering/]: Couldn't fully analyze 1 tertium_chestplate, missing knowledge for {1 prudentium_chestplate=1.0}
# [22:24:32] [Server thread/INFO] [immersiveengineering/]: Couldn't fully analyze 1 imperium_chestplate, missing knowledge for {1 tertium_chestplate=1.0}
# [22:24:32] [Server thread/INFO] [immersiveengineering/]: Couldn't fully analyze 1 pneumatic_leggings, missing knowledge for {1 compressed_iron_leggings=1.0}
# [22:24:32] [Server thread/INFO] [immersiveengineering/]: Couldn't fully analyze 1 imperium_hoe, missing knowledge for {1 tertium_hoe=1.0}
# [22:24:32] [Server thread/INFO] [immersiveengineering/]: Couldn't fully analyze 1 jet_suit_helmet, missing knowledge for {1 netherite_space_helmet=1.0}
# [22:24:32] [Server thread/INFO] [immersiveengineering/]: Couldn't fully analyze 1 supremium_axe, missing knowledge for {1 imperium_axe=1.0}
# [22:24:32] [Server thread/INFO] [immersiveengineering/]: Couldn't fully analyze 1 supremium_sickle, missing knowledge for {1 imperium_sickle=1.0}
# [22:24:32] [Server thread/INFO] [immersiveengineering/]: Couldn't fully analyze 1 supremium_boots, missing knowledge for {1 imperium_boots=1.0}
# [22:24:32] [Server thread/INFO] [immersiveengineering/]: Couldn't fully analyze 1 prudentium_chestplate, missing knowledge for {1 inferium_chestplate=1.0}
# [22:24:32] [Server thread/INFO] [immersiveengineering/]: Couldn't fully analyze 1 supremium_pickaxe, missing knowledge for {1 imperium_pickaxe=1.0}
# [22:24:32] [Server thread/INFO] [immersiveengineering/]: Couldn't fully analyze 1 prudentium_scythe, missing knowledge for {1 inferium_scythe=1.0}
# [22:24:32] [Server thread/INFO] [immersiveengineering/]: Couldn't fully analyze 1 tertium_pickaxe, missing knowledge for {1 prudentium_pickaxe=1.0}
# [22:24:32] [Server thread/INFO] [immersiveengineering/]: Couldn't fully analyze 1 supremium_scythe, missing knowledge for {1 imperium_scythe=1.0}
# [22:24:32] [Server thread/INFO] [immersiveengineering/]: Couldn't fully analyze 1 netherite_space_pants, missing knowledge for {1 netherite_leggings=1.0}
# [22:24:32] [Server thread/INFO] [immersiveengineering/]: Couldn't fully analyze 1 prudentium_leggings, missing knowledge for {1 inferium_leggings=1.0}
# [22:24:32] [Server thread/INFO] [immersiveengineering/]: Couldn't fully analyze 1 supremium_chestplate, missing knowledge for {1 imperium_chestplate=1.0}
# [22:24:32] [Server thread/INFO] [immersiveengineering/]: Couldn't fully analyze 1 imperium_axe, missing knowledge for {1 tertium_axe=1.0}
# [22:24:32] [Server thread/INFO] [immersiveengineering/]: Couldn't fully analyze 1 prudentium_sickle, missing knowledge for {1 inferium_sickle=1.0}
# [22:24:32] [Server thread/INFO] [immersiveengineering/]: Couldn't fully analyze 1 compressed_iron_chestplate, missing knowledge for {1 leather_chestplate=1.0}
# [22:24:32] [Server thread/INFO] [immersiveengineering/]: Couldn't fully analyze 1 jet_suit, missing knowledge for {1 netherite_space_suit=1.0}
# [22:24:32] [Server thread/INFO] [immersiveengineering/]: Couldn't fully analyze 1 netherite_space_boots, missing knowledge for {1 netherite_boots=1.0}
# [22:24:32] [Server thread/INFO] [immersiveengineering/]: Couldn't fully analyze 1 supremium_hoe, missing knowledge for {1 imperium_hoe=1.0}
# [22:24:32] [Server thread/INFO] [immersiveengineering/]: Couldn't fully analyze 1 netherite_space_helmet, missing knowledge for {1 netherite_helmet=1.0}
# [22:24:32] [Server thread/INFO] [immersiveengineering/]: Couldn't fully analyze 1 inferium_scythe, missing knowledge for {1 diamond_scythe=1.0}
# [22:24:32] [Server thread/INFO] [immersiveengineering/]: Couldn't fully analyze 1 inferium_boots, missing knowledge for {1 diamond_boots=1.0}
# [22:24:32] [Server thread/INFO] [immersiveengineering/]: Couldn't fully analyze 1 imperium_sword, missing knowledge for {1 tertium_sword=1.0}
# [22:24:32] [Server thread/INFO] [immersiveengineering/]: Couldn't fully analyze 1 tertium_shovel, missing knowledge for {1 prudentium_shovel=1.0}
# [22:24:32] [Server thread/INFO] [immersiveengineering/]: Couldn't fully analyze 1 compressed_iron_leggings, missing knowledge for {1 leather_leggings=1.0}
# [22:24:32] [Server thread/INFO] [immersiveengineering/]: Couldn't fully analyze 1 tertium_axe, missing knowledge for {1 prudentium_axe=1.0}
# [22:24:32] [Server thread/INFO] [immersiveengineering/]: Couldn't fully analyze 1 prudentium_hoe, missing knowledge for {1 inferium_hoe=1.0}
# [22:24:32] [Server thread/INFO] [immersiveengineering/]: Couldn't fully analyze 1 tertium_boots, missing knowledge for {1 prudentium_boots=1.0}
# [22:24:32] [Server thread/INFO] [immersiveengineering/]: Couldn't fully analyze 1 imperium_leggings, missing knowledge for {1 tertium_leggings=1.0}
# [22:24:32] [Server thread/INFO] [immersiveengineering/]: Couldn't fully analyze 1 supremium_sword, missing knowledge for {1 imperium_sword=1.0}
# [22:24:32] [Server thread/INFO] [immersiveengineering/]: Couldn't fully analyze 1 tertium_scythe, missing knowledge for {1 prudentium_scythe=1.0}
# [22:24:32] [Server thread/INFO] [immersiveengineering/]: Couldn't fully analyze 1 prudentium_axe, missing knowledge for {1 inferium_axe=1.0}
# [22:24:32] [Server thread/INFO] [immersiveengineering/]: Couldn't fully analyze 1 compressed_iron_boots, missing knowledge for {1 leather_boots=1.0}
# [22:24:32] [Server thread/INFO] [immersiveengineering/]: Couldn't fully analyze 1 imperium_shovel, missing knowledge for {1 tertium_shovel=1.0}
# [22:24:32] [Server thread/INFO] [immersiveengineering/]: Couldn't fully analyze 1 compressed_iron_helmet, missing knowledge for {1 leather_helmet=1.0}
# [22:24:32] [Server thread/INFO] [immersiveengineering/]: Couldn't fully analyze 1 prudentium_boots, missing knowledge for {1 inferium_boots=1.0}
# [22:24:32] [Server thread/INFO] [immersiveengineering/]: Couldn't fully analyze 1 inferium_chestplate, missing knowledge for {1 diamond_chestplate=1.0}
# [22:24:32] [Server thread/INFO] [immersiveengineering/]: Couldn't fully analyze 1 tertium_sword, missing knowledge for {1 prudentium_sword=1.0}
# [22:24:32] [Server thread/INFO] [immersiveengineering/]: Couldn't fully analyze 1 jet_suit_pants, missing knowledge for {1 netherite_space_pants=1.0}
# [22:24:32] [Server thread/INFO] [immersiveengineering/]: Couldn't fully analyze 1 inferium_shovel, missing knowledge for {1 diamond_shovel=1.0}
# [22:24:32] [Server thread/INFO] [immersiveengineering/]: Couldn't fully analyze 1 inferium_leggings, missing knowledge for {1 diamond_leggings=1.0}
# [22:24:32] [Server thread/INFO] [immersiveengineering/]: Couldn't fully analyze 1 inferium_pickaxe, missing knowledge for {1 diamond_pickaxe=1.0}
# [22:24:32] [Server thread/INFO] [immersiveengineering/]: Finished recipe profiler for Arc Recycling, took 300 milliseconds
# [22:24:32] [Server thread/WARN] [ModernFix/]: Dedicated server took 147.087 seconds to load
# [22:24:34] [Server thread/WARN] [minecraft/MinecraftServer]: Can't keep up! Is the server overloaded? Running 2176ms or 43 ticks behind
# [22:24:51] [Server thread/INFO] [minecraft/PlayerList]: santutu[/[::1]:54864] logged in with entity id 1196 at (-67.5, 72.0, 19.5)
# [22:24:51] [Server thread/INFO] [Modonomicon/]: Building books ...
# [22:24:51] [Server thread/WARN] [Modonomicon/]: Recipe minecraft:iron_ingot_from_blasting_iron_ore (of type minecraft:blasting) not found.
# [22:24:51] [Server thread/WARN] [Modonomicon/]: Recipe minecraft:netherite_axe_smithing_does_not_exist (of type minecraft:smithing) not found.
# [22:24:51] [Server thread/INFO] [Modonomicon/]: Books built.
# [22:24:51] [Server thread/INFO] [Modonomicon/]: Adding read conditions ...
# [22:24:51] [Server thread/INFO] [Modonomicon/]: Read conditions added.
# [22:24:52] [Server thread/INFO] [minecraft/MinecraftServer]: santutu joined the game
# [22:24:52] [Netty Epoll Server IO #7/INFO] [immersiveengineering/]: Recipes for potions: ars_nouveau:recovery_potion, irons_spellbooks:instant_mana_three, apotheosis:wither, apotheosis:knowledge, irons_spellbooks:instant_mana_four, potionsmaster:vibranium_sight, minecraft:long_slow_falling, ars_nouveau:recovery_potion_long, minecraft:long_invisibility, minecraft:strong_slowness, apotheosis:sundering, apotheosis:grievous, quark:long_resilience, minecraft:harming, potionsmaster:platinum_sight, minecraft:long_regeneration, potionsmaster:redstone_sight, ars_elemental:enderference_potion_long, potionsmaster:copper_sight, ars_nouveau:blasting_potion, minecraft:long_slowness, apotheosis:strong_absorption, apotheosis:long_fatigue, ars_nouveau:shielding_potion_long, ars_nouveau:mana_regen_potion_long, minecraft:long_weakness, minecraft:weakness, tombstone:restoration, minecraft:fire_resistance, potionsmaster:diamond_sight, minecraft:invisibility, potionsmaster:emerald_sight, quark:strong_resilience, minecraft:long_swiftness, potionsmaster:quartz_sight, potionsmaster:nickel_sight, tombstone:frostbite, apotheosis:strong_vitality, apotheosis:strong_grievous, minecraft:strong_poison, apotheosis:long_absorption, minecraft:luck, tombstone:darkness, minecraft:water, minecraft:water_breathing, minecraft:strong_regeneration, ars_nouveau:freezing_potion_long, ars_nouveau:spell_damage_potion, ars_nouveau:shielding_potion_strong, tombstone:bait, minecraft:long_night_vision, minecraft:long_fire_resistance, minecraft:strong_swiftness, irons_spellbooks:instant_mana_two, potionsmaster:lapis_sight, ars_nouveau:spell_damage_potion_strong, tombstone:spectral, potionsmaster:allthemodium_sight, potionsmaster:netherite_sight, ars_elemental:enderference_potion, ars_elemental:shock_potion, apotheosis:absorption, minecraft:long_water_breathing, apotheosis:haste, quark:resilience, apotheosis:long_vitality, minecraft:regeneration, apotheosis:extra_long_flying, apotheosis:long_resistance, ars_nouveau:freezing_potion, minecraft:slowness, irons_spellbooks:instant_mana_one, potionsmaster:zinc_sight, potionsmaster:unobtainium_sight, apotheosis:strong_wither, minecraft:swiftness, minecraft:long_turtle_master, ars_nouveau:blasting_potion_strong, deeperdarker:long_sculk_affinity, minecraft:strong_leaping, minecraft:strength, minecraft:long_poison, apotheosis:strong_resistance, apotheosis:long_sundering, minecraft:strong_strength, potionsmaster:coal_sight, apotheosis:strong_knowledge, minecraft:turtle_master, minecraft:long_strength, potionsmaster:bismuth_sight, potionsmaster:crimsoniron_sight, apotheosis:strong_sundering, apotheosis:long_grievous, potionsmaster:iron_sight, minecraft:long_leaping, minecraft:slow_falling, potionsmaster:osmium_sight, potionsmaster:gold_sight, minecraft:awkward, ars_nouveau:mana_regen_potion, apotheosis:long_flying, minecraft:healing, potionsmaster:tin_sight, apotheosis:long_haste, apotheosis:fatigue, minecraft:strong_harming, minecraft:strong_turtle_master, potionsmaster:silver_sight, potionsmaster:aluminum_sight, apotheosis:long_wither, tombstone:discretion, apotheosis:resistance, apotheosis:vitality, ars_nouveau:mana_regen_potion_strong, ars_elemental:shock_potion_long, potionsmaster:lead_sight, deeperdarker:sculk_affinity, ars_nouveau:shielding_potion, minecraft:night_vision, ars_nouveau:freezing_potion_strong, ars_nouveau:blasting_potion_long, minecraft:leaping, minecraft:poison, apotheosis:strong_haste, tombstone:earthly_garden, apotheosis:strong_fatigue, ars_nouveau:spell_damage_potion_long, apotheosis:flying, apotheosis:long_knowledge, minecraft:strong_healing, apotheosis:levitation, ars_nouveau:recovery_potion_strong, potionsmaster:uranium_sight
# [22:24:52] [Server thread/INFO] [minecraft/MinecraftServer]: santutu has reached the goal [Easter]
# [22:24:52] [Server thread/INFO] [Jade/]: Syncing config to santutu (51925a8f-ffa2-3150-851b-334b69cd6dd2)
# [22:24:53] [Server thread/WARN] [minecraft/MinecraftServer]: Can't keep up! Is the server overloaded? Running 2001ms or 40 ticks behind
# [22:27:58] [Server thread/INFO] [minecraft/ServerGamePacketListenerImpl]: santutu lost connection: Disconnected
# [22:27:58] [Server thread/INFO] [minecraft/MinecraftServer]: santutu left the game
# >
